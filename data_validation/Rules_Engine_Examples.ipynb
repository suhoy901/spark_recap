# %%
# %scala
import com.databricks.labs.validation.utils.Structures._
import com.databricks.labs.validation._
import org.apache.spark.sql.functions._
import org.apache.spark.sql.{Column, DataFrame}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import com.databricks.labs.validation.utils.Structures._
# import com.databricks.labs.validation._
# import org.apache.spark.sql.functions._
# import org.apache.spark.sql.{Column, DataFrame}
# </div>

# %%
# %scala
object Lookups {
  final val validStoreIDs = Array(1001, 1002)
  final val validRegions = Array("Northeast", "Southeast", "Midwest", "Northwest", "Southcentral", "Southwest")
  final val validSkus = Array(123456, 122987,123256, 173544, 163212, 365423, 168212)
}

val df = sc.parallelize(Seq(
    ("Northwest", 1001, 123456, 9.32, 8.99, 4.23, "2020-02-01 00:00:00.000"),
    ("Northwest", 1001, 123256, 19.99, 16.49, 12.99, "2020-02-01"),
    ("Northwest", 1001, 123456, 0.99, 0.99, 0.10, "2020-02-01"),
    ("Northwest", 1001, 123456, 0.98, 0.90, 0.10, "2020-02-01"), // non_distinct sku
    ("Northwst", 1001, 123456, 0.99, 0.99, 0.10, "2020-02-01"), // Misspelled Region
    ("Northwest", 1002, 122987, 9.99, 9.49, 6.49, "2021-02-01"), // Invalid Date/Timestamp
    ("Northwest", 1002, 173544, 1.29, 0.99, 1.23, "2020-02-01"),
    ("Northwest", 1002, 168212, 3.29, 1.99, 1.23, "2020-02-01"),
    ("Northwest", 1002, 365423, 1.29, 0.99, 1.23, "2020-02-01"),
    ("Northwest", 1002, 3897615, 14.99, 129.99, 1.23, "2020-02-01"),
    ("Northwest", 1003, 163212, 3.29, 1.99, 1.23, "2020-02-01") // Invalid numeric store_id groupby test
  )).toDF("region", "store_id", "sku", "retail_price", "scan_price", "cost", "create_ts")
    .withColumn("create_ts", 'create_ts.cast("timestamp"))
    .withColumn("create_dt", 'create_ts.cast("date"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">defined object Lookups
# df: org.apache.spark.sql.DataFrame = [region: string, store_id: int ... 6 more fields]
# </div>

# %%
# %scala
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>store_id</th><th>sku</th><th>retail_price</th><th>scan_price</th><th>cost</th><th>create_ts</th><th>create_dt</th></tr></thead><tbody><tr><td>Northwest</td><td>1001</td><td>123456</td><td>9.32</td><td>8.99</td><td>4.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1001</td><td>123256</td><td>19.99</td><td>16.49</td><td>12.99</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1001</td><td>123456</td><td>0.99</td><td>0.99</td><td>0.1</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1001</td><td>123456</td><td>0.98</td><td>0.9</td><td>0.1</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwst</td><td>1001</td><td>123456</td><td>0.99</td><td>0.99</td><td>0.1</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1002</td><td>122987</td><td>9.99</td><td>9.49</td><td>6.49</td><td>2021-02-01T00:00:00.000+0000</td><td>2021-02-01</td></tr><tr><td>Northwest</td><td>1002</td><td>173544</td><td>1.29</td><td>0.99</td><td>1.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1002</td><td>168212</td><td>3.29</td><td>1.99</td><td>1.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1002</td><td>365423</td><td>1.29</td><td>0.99</td><td>1.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1002</td><td>3897615</td><td>14.99</td><td>129.99</td><td>1.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr><tr><td>Northwest</td><td>1003</td><td>163212</td><td>3.29</td><td>1.99</td><td>1.23</td><td>2020-02-01T00:00:00.000+0000</td><td>2020-02-01</td></tr></tbody></table></div>

# %% [markdown]
# # Build Rules

# %%
# %scala
def getDiscountPercentage(retailPrice: Column, scanPrice: Column): Column = {
  (retailPrice - scanPrice) / retailPrice
}

// Example of standalone simple rule
val validateRetailPrice = Rule("Retail_Price_Validation", col("retail_price"), Bounds(0.0, 6.99))

// Example of Array of rules of different types
val specializedRules = Array(
  // Example of aggregate column
  Rule("Reasonable_sku_counts", count(col("sku")), Bounds(lower = 20.0, upper = 200.0)),
  // Example of calculated column from optimized UDF
  Rule("Max_allowed_discount",
    max(getDiscountPercentage(col("retail_price"), col("scan_price"))),
    Bounds(upper = 90.0)),
  // Example distinct values rule
  Rule("Unique_Skus", countDistinct("sku"), Bounds(upper = 1.0))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">getDiscountPercentage: (retailPrice: org.apache.spark.sql.Column, scanPrice: org.apache.spark.sql.Column)org.apache.spark.sql.Column
# validateRetailPrice: com.databricks.labs.validation.Rule = com.databricks.labs.validation.Rule@2340d3bf
# specializedRules: Array[com.databricks.labs.validation.Rule] = Array(com.databricks.labs.validation.Rule@6b6ee323, com.databricks.labs.validation.Rule@209b4e42, com.databricks.labs.validation.Rule@36c543f8)
# </div>

# %%
# %scala
// It's common to generate many min/max boundaries. These can be generated easily
// The generator function can easily be extended or overridden to satisfy more complex requirements
val minMaxPriceDefs = Array(
  MinMaxRuleDef("MinMax_Sku_Price", col("retail_price"), Bounds(0.0, 29.99)),
  MinMaxRuleDef("MinMax_Scan_Price", col("scan_price"), Bounds(0.0, 29.99)),
  MinMaxRuleDef("MinMax_Cost", col("cost"), Bounds(0.0, 12.0))
)

// Generate the array of Rules from the minmax generator
val minMaxPriceRules = RuleSet.generateMinMaxRules(minMaxPriceDefs: _*)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">minMaxPriceDefs: Array[com.databricks.labs.validation.utils.Structures.MinMaxRuleDef] = Array(MinMaxRuleDef(MinMax_Sku_Price,retail_price,Bounds(0.0,29.99),WrappedArray()), MinMaxRuleDef(MinMax_Scan_Price,scan_price,Bounds(0.0,29.99),WrappedArray()), MinMaxRuleDef(MinMax_Cost,cost,Bounds(0.0,12.0),WrappedArray()))
# minMaxPriceRules: Array[com.databricks.labs.validation.Rule] = Array(com.databricks.labs.validation.Rule@14457935, com.databricks.labs.validation.Rule@6c406cb6, com.databricks.labs.validation.Rule@26e2d1f6, com.databricks.labs.validation.Rule@1cef368c, com.databricks.labs.validation.Rule@23dc68f5, com.databricks.labs.validation.Rule@4c1685e4)
# </div>

# %%
# %scala
// Numerical categorical rules. Build create a list of values to be validated against.
val catNumerics = Array(
  // Only allow store_ids in my validStoreIDs lookup
  Rule("Valid_Stores", col("store_id"), Lookups.validStoreIDs),
  // Validate against a pre-built list of skus that have been verified to be accurate
  // Currently this is manually created for demo but can easily be created from a dataframe, etc.
  Rule("Valid_Skus", col("sku"), Lookups.validSkus)
)

// Validate strings as well as numericals. They don't need to be in a separate array, it's just done here for demonstration
val catStrings = Array(
  Rule("Valid_Regions", col("region"), Lookups.validRegions)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">catNumerics: Array[com.databricks.labs.validation.Rule] = Array(com.databricks.labs.validation.Rule@6cce83c5, com.databricks.labs.validation.Rule@4eb714cf)
# catStrings: Array[com.databricks.labs.validation.Rule] = Array(com.databricks.labs.validation.Rule@6ec9554)
# </div>

# %% [markdown]
# # Validate DataFrame
# Dataframes can be simple or a Seq of columns can be passed in as "bys" for the DataFrame to be grouped by. <br>
# If the dataframe is grouped validations will be per group

# %%
# %scala
// The Validate function will return two values, a report DF to review failures and `passed` as a boolean
// If the `passed` == true then all rules passed successfully, otherwise, at least one rule failed.

// Notice the builder patthern. The idea is to buld up your rules and then add them to your RuleSet[s].
// RuleSets can be combined to using the RuleSet.add(ruleSet: RuleSet) method
val (rulesReport, passed) = RuleSet(df)
  .add(specializedRules)
  .add(minMaxPriceRules)
  .add(catNumerics)
  .add(catStrings)
  .validate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">rulesReport: org.apache.spark.sql.DataFrame = [Rule_Name: string, Rule_Type: string ... 3 more fields]
# passed: Boolean = false
# </div>

# %%
# %scala
passed
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>

# %%
# %scala
display(rulesReport)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Rule_Name</th><th>Rule_Type</th><th>Validation_Values</th><th>Invalid_Count</th><th>Failed</th></tr></thead><tbody><tr><td>MinMax_Cost_max</td><td>bounds</td><td>List(null, null, List(0.0, 12.0), null)</td><td>1</td><td>true</td></tr><tr><td>MinMax_Scan_Price_max</td><td>bounds</td><td>List(null, null, List(0.0, 29.99), null)</td><td>1</td><td>true</td></tr><tr><td>Reasonable_sku_counts</td><td>bounds</td><td>List(null, null, List(20.0, 200.0), null)</td><td>1</td><td>true</td></tr><tr><td>Unique_Skus</td><td>bounds</td><td>List(null, null, List(-Infinity, 1.0), null)</td><td>1</td><td>true</td></tr><tr><td>Valid_Regions</td><td>validStrings</td><td>List(null, null, null, List(Northeast, Southeast, Midwest, Northwest, Southcentral, Southwest))</td><td>1</td><td>true</td></tr><tr><td>Valid_Skus</td><td>validNumerics</td><td>List(null, List(123456.0, 122987.0, 123256.0, 173544.0, 163212.0, 365423.0, 168212.0), null, null)</td><td>1</td><td>true</td></tr><tr><td>Valid_Stores</td><td>validNumerics</td><td>List(null, List(1001.0, 1002.0), null, null)</td><td>1</td><td>true</td></tr><tr><td>Max_allowed_discount</td><td>bounds</td><td>List(null, null, List(-Infinity, 90.0), null)</td><td>0</td><td>false</td></tr><tr><td>MinMax_Cost_min</td><td>bounds</td><td>List(null, null, List(0.0, 12.0), null)</td><td>0</td><td>false</td></tr><tr><td>MinMax_Scan_Price_min</td><td>bounds</td><td>List(null, null, List(0.0, 29.99), null)</td><td>0</td><td>false</td></tr><tr><td>MinMax_Sku_Price_max</td><td>bounds</td><td>List(null, null, List(0.0, 29.99), null)</td><td>0</td><td>false</td></tr><tr><td>MinMax_Sku_Price_min</td><td>bounds</td><td>List(null, null, List(0.0, 29.99), null)</td><td>0</td><td>false</td></tr></tbody></table></div>

# %%
# %scala
// Grouped Dataframe
// Let's assume we want to perform validation by some grouping of one or many columns
val (rulesReport, passed) = RuleSet(df, Array("store_id"))
  .add(specializedRules)
  .add(minMaxPriceRules)
  .add(catNumerics)
  .add(catStrings)
  .validate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">rulesReport: org.apache.spark.sql.DataFrame = [store_id: int, Rule_Name: string ... 4 more fields]
# passed: Boolean = false
# </div>

# %%
# %scala
val (rulesReport, passed) = RuleSet(df, "store_id")
  .add(specializedRules)
  .add(minMaxPriceRules)
  .add(catNumerics)
  .add(catStrings)
  .validate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">rulesReport: org.apache.spark.sql.DataFrame = [store_id: int, Rule_Name: string ... 4 more fields]
# passed: Boolean = false
# </div>

# %% [markdown]
# ## Date Validations
# To be implemented.
