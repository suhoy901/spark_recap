# %% [markdown]
# ### Databricks와 ADLS2 마운트 설정

# %%
# 데이터브릭스 
configs = {
  "fs.azure.account.auth.type": "OAuth",
  "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  # 클라이언트 ID
  "fs.azure.account.oauth2.client.id": "d7e454af-c6ae-4d35-ac88-3e6ba24bc7f2",
  
  # secret
  "fs.azure.account.oauth2.client.secret": "w9R0qnVS.3~WBLQi49b-.-5mGGCaGf4h.c",
  
  # https://login.microsoftonline.com/{}/oauth2/token"
  # directory id
  "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/ee6410b7-317c-4e6b-9dc6-7dd7ec723201/oauth2/token"}

 
dbutils.fs.mount(
  # abfss://{0}@{1}.dfs.core.windows.net/
  ## {0} : container, {1} : storage account name
  source = "abfss://onpremfilesys@cdadls2.dfs.core.windows.net/",
  mount_point = "/mnt/cdpocmount",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
dbutils.fs.ls("/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/&#39;, name=&#39;mnt/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/tmp/&#39;, name=&#39;tmp/&#39;, size=0)]</div>

# %% [markdown]
# 확인한 결과 잘 마운트된 것을 알 수 있음

# %%
dbutils.fs.ls("/mnt/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/mnt/cdpocmount/&#39;, name=&#39;cdpocmount/&#39;, size=0)]</div>

# %%
dbutils.fs.ls("/mnt/cdpocmount/") # april과 chugdahm 폴더가 존재함을 확인
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [FileInfo(path=&#39;dbfs:/mnt/cdpocmount/april/&#39;, name=&#39;april/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/cdpocmount/chungdahm/&#39;, name=&#39;chungdahm/&#39;, size=0)]</div>
