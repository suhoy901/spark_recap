# %%
dbutils.fs.ls("/mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: [FileInfo(path=&#39;dbfs:/mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1079621_20200315162506000.txt&#39;, name=&#39;1079621_20200315162506000.txt&#39;, size=21777),
#  FileInfo(path=&#39;dbfs:/mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1079621_20200315162749000.txt&#39;, name=&#39;1079621_20200315162749000.txt&#39;, size=10034),
#  FileInfo(path=&#39;dbfs:/mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1079621_20200315164558000.txt&#39;, name=&#39;1079621_20200315164558000.txt&#39;, size=55675),
# ...

# %%
# %sql

# %%
from pyspark.sql.functions import *
from pprint import pprint
import pandas as pd
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#vena_talk_total_json_pd = pd.read_json("/dbfs/mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114709000.txt")
#vena_talk_total_json_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
VENA_Talk_Total_DF = spark.read.format("json").option("inferSchema", "true").option("header", "true").load("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/*.txt")


# extra_data struct라는 새로운 데이터 타입이 등장. 기존 데이터 정의서에 없는 데이터
VENA_Talk_Total_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- SR_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- data: string (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- study_code: string (nullable = true)
# -- com_id: long (nullable = true)
# -- evaluation_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- data: string (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- study_code: string (nullable = true)
# ...

# %% [markdown]
# ### Pyspark -> PD

# %%
# nested 형태의 스키마를 갖는 spark 데이터프레임의 경우 pandas 데이터프레임으로 변경시킬 때 모든 하부의 스키마 정보가 소실됨
VENA_Talk_Total_DF_py = VENA_Talk_Total_DF.toPandas()
VENA_Talk_Total_DF_py.head()

print(VENA_Talk_Total_DF_py.columns)

## TOBE : feature 처리
for col in VENA_Talk_Total_DF_py:
  if VENA_Talk_Total_DF[col].dtype == "object":
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SR_data</th>
#       <th>com_id</th>
#       <th>evaluation_data</th>
#       <th>extra_data</th>
#       <th>extra_date</th>
#       <th>g_seq</th>
#       <th>lv_cd</th>
#       <th>sem_id</th>
#       <th>study_data</th>
#       <th>study_time</th>
#       <th>top_cors_id</th>
#       <th>topic_code</th>
#       <th>topic_title</th>
#       <th>total_score</th>
#       <th>total_star</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[({"analysisResult":{"endTime":"7380","progres...</td>
#       <td>1076</td>
#       <td>[(63, AI_PA, 1, evaluation), (79, AI_CR, 2, ev...</td>
# ...

# %%
from pyspark.sql.functions import *

display(VENA_Talk_Total_DF.select("extra_data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
VENA_Talk_Total_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- SR_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- data: string (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- study_code: string (nullable = true)
# -- com_id: long (nullable = true)
# -- evaluation_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- data: string (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- study_code: string (nullable = true)
# ...

# %%
from itertools import chain
from pyspark.sql.types import *
from pyspark.sql.functions import udf
from pyspark.sql.functions import col

flatten_long = udf(lambda x: list(chain.from_iterable(x)), ArrayType(LongType()))
flatten_string = udf(lambda x: list(chain.from_iterable(x)), ArrayType(StringType()))

# flatten_long()

## 1. evaluation data
VENA_Talk_Total_DF = VENA_Talk_Total_DF.withColumn('ev_data_flatten', col("evaluation_data.data")) # 새로운 컬럼을 생성함
VENA_Talk_Total_DF = VENA_Talk_Total_DF.withColumn("ev_element_flatten", col("evaluation_data.element"))
VENA_Talk_Total_DF = VENA_Talk_Total_DF.withColumn("ev_pageorderseq_flatten", col("evaluation_data.page_order_seq"))
VENA_Talk_Total_DF = VENA_Talk_Total_DF.withColumn("ev_study_code_flatten", col("evaluation_data.study_code"))



#### dataframe에 list의 형태로 들어있는 경우 연산작업
# sample_df_1081.withColumn("srdata_data_asr_progresscode", col("SR_data.data.analysisResult.progressCode")).select("srdata_data_asr_progresscode").rdd.map(lambda Word : (Word,1)).collect()


## 2. SR_data : 예시에서는 40개의 seq가 있음
#### expression 예시 :  sample_df_1081.withColumn("srdata_studycode", expr("slice(SR_data.study_code, 1, 3)")).show()
sample_df_1076 = sample_df_1076.withColumn("srdata_studycode", col("SR_data.study_code"))
sample_df_1076 = sample_df_1076.withColumn("srdata_pageorderseq", col("SR_data.page_order_seq"))
sample_df_1076 = sample_df_1076.withColumn("srdata_element", col("SR_data.element"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_ticketid", col("SR_data.data.ticketID"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_endtime", col("SR_data.data.analysisResult.endTime"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_progresscode", col("SR_data.data.analysisResult.progressCode"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_reqdataindex", col("SR_data.data.analysisResult.reqDataIndex"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_result", col("SR_data.data.analysisResult.result"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_score", col("SR_data.data.analysisResult.score"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_starttime", col("SR_data.data.analysisResult.startTime"))
# sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_wordresult", sample_df_1076.selectExpr("SR_data.data.analysisResult.wordResult"))
sample_df_1076 = sample_df_1076.withColumn("srdata_data_asr_wordresult", col("SR_data.data.analysisResult.wordResult"))


## 3. study_data
sample_df_1076 = sample_df_1076.withColumn("studydata_studycode", col("study_data.study_code"))
sample_df_1076 = sample_df_1076.withColumn("studydata_pageorderseq", col("study_data.page_order_seq"))

# ["clean","I clean my bathroom regularly.","attack","Viruses will attack when your immune system is weak.", ...]
sample_df_1076 = sample_df_1076.withColumn("studydata_textdata", col("study_data.text_data"))
sample_df_1076 = sample_df_1076.withColumn("studydata_audiodata", col("study_data.audio_data"))
sample_df_1076 = sample_df_1076.withColumn("studydata_isstudent", col("study_data.is_student"))

#display(sample_df_1076.withColumn("studydata_textdata", col("study_data.text_data")).limit(5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 1. VENA Talk 1081
# - Pyspark의 데이터 타입을 활용하여 JSON 스키마를 설정함
# ```python
# sample = spark.read.schema(schema_sample_1081).json("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114445000.txt")
# sample2 = spark.read.format("json").option("inferSchema", "true").option("header", "true").load("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114445000.txt")
# ```

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

venatalk_1081_schema = StructType([
  StructField("sem_id", StringType(), True),
  StructField("top_cors_id", StringType(), True),
  StructField("lv_cd", StringType(), True),
  StructField("g_seq", StringType(), True),
  StructField("com_id", LongType(), True),
  StructField("topic_code", StringType(), True),
  StructField("topic_title", StringType(), True),
  StructField("study_time", LongType(), True),
  StructField("evaluation_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", LongType(), True)
                  ]), True
                ), True  
  ),
  StructField("study_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("text_data", StringType(), True),
                    StructField("audio_data", StringType(), True),
                    StructField("is_student", LongType(), True)
                  ]), True), True),
  StructField("SR_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", StructType([
                      StructField("analysisResult", StructType([
                          StructField("endTime", StringType(), True),
                          StructField("progressCode", StringType(), True),
                          StructField("reqDataIndex", StringType(), True),
                          StructField("result", StringType(), True),
                          StructField("score", StringType(), True),
                          StructField("startTime", StringType(), True)
                      ]), True),
                      StructField("ticketID", StringType(), True)
                    ]), True)
                  ]), True))
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
venatalk_1081_DF = spark.read.schema(venatalk_1081_schema).json("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114445000.txt")

venatalk_1081_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- sem_id: string (nullable = true)
# -- top_cors_id: string (nullable = true)
# -- lv_cd: string (nullable = true)
# -- g_seq: string (nullable = true)
# -- com_id: long (nullable = true)
# -- topic_code: string (nullable = true)
# -- topic_title: string (nullable = true)
# -- study_time: long (nullable = true)
# -- evaluation_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- study_code: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- data: long (nullable = true)
# ...

# %%
display(venatalk_1081_DF.limit(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# - 자동으로 inferschema를 설정하여 JSON을 읽어드리는 경우

# %%
venatalk_1081_infer_DF = spark.read.format("json").option("inferSchema", "true").option("header", "true").load("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114445000.txt")
venatalk_1081_infer_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- SR_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- data: struct (nullable = true)
#     |    |    |-- analysisResult: struct (nullable = true)
#     |    |    |    |-- endTime: string (nullable = true)
#     |    |    |    |-- progressCode: string (nullable = true)
#     |    |    |    |-- reqDataIndex: string (nullable = true)
#     |    |    |    |-- result: string (nullable = true)
#     |    |    |    |-- score: string (nullable = true)
#     |    |    |    |-- startTime: string (nullable = true)
#     |    |    |-- ticketId: string (nullable = true)
# ...

# %%
from pprint import pprint
evaluation_json = venatalk_1081_infer_DF.select("evaluation_data").toPandas() 
print(evaluation_json.shape)
evaluation_json.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(1, 1)
# &lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
# evaluation_data    1 non-null object
# dtypes: object(1)
# memory usage: 88.0+ bytes
# </div>

# %%
type(evaluation_json['evaluation_data']) # Series의 형태로 변경됨
evaluation_numpy = evaluation_json['evaluation_data'].to_numpy()
evaluation_numpy.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: (1,)</div>

# %%
evaluation_numpy[0] # 알아서 언패킹해서 차후 작업을 수행하면 됨. Row()객체는???
# evaluation_numpy --> pprint 의미가 없음(데이터브릭스를 어떻게 이해해야할까)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">array([list([Row(data=0, element=&#39;AI_PA&#39;, page_order_seq=1, study_code=&#39;evaluation&#39;), Row(data=0, element=&#39;AI_CR&#39;, page_order_seq=2, study_code=&#39;evaluation&#39;), Row(data=100, element=&#39;AI_SS&#39;, page_order_seq=3, study_code=&#39;evaluation&#39;), Row(data=0, element=&#39;AI_SV&#39;, page_order_seq=4, study_code=&#39;evaluation&#39;), Row(data=0, element=&#39;AI_SL&#39;, page_order_seq=5, study_code=&#39;evaluation&#39;)])],
#       dtype=object)
# </div>

# %% [markdown]
# ### 2. VENA Talk 1082 Schema

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

venatalk_1082_schema = StructType([
  StructField("sem_id", StringType(), True),
  StructField("top_cors_id", StringType(), True),
  StructField("lv_cd", StringType(), True),
  StructField("g_seq", StringType(), True),
  StructField("com_id", LongType(), True),
  StructField("topic_code", StringType(), True),
  StructField("topic_title", StringType(), True),
  StructField("study_time", LongType(), True),
  StructField("evaluation_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", LongType(), True)
                  ]), True
                ), True  
  ),
  StructField("study_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("text_data", StringType(), True),
                    StructField("audio_data", StringType(), True),
                    StructField("is_student", LongType(), True)
                  ]), True), True),
  StructField("SR_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", StructType([
                      StructField("analysisResult", StructType([
                          StructField("endTime", StringType(), True),
                          StructField("progressCode", StringType(), True),
                          StructField("reqDataIndex", StringType(), True),
                          StructField("result", StringType(), True),
                          StructField("score", StringType(), True),
                          StructField("startTime", StringType(), True)
                      ]), True),
                      StructField("ticketID", StringType(), True)
                    ]), True)
                  ]), True))
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import lit

venatalk_prod = spark.createDataFrame(sc.emptyRDD(), venatalk_1082_schema)
venatalk_prod = venatalk_prod.withColumn("std_id", lit("null"))

venatalk_prod.write.option('path', "/mnt/cdpocmount/FileSysTables/1082_venatalk_test/venatalk_prod.parquet").saveAsTable("venatalk_prod")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

select * from venatalk_prod
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sem_id</th><th>top_cors_id</th><th>lv_cd</th><th>g_seq</th><th>com_id</th><th>topic_code</th><th>topic_title</th><th>study_time</th><th>evaluation_data</th><th>study_data</th><th>SR_data</th><th>std_id</th></tr></thead><tbody></tbody></table></div>

# %%
venatalk_1082_DF = spark.read.format("json").schema(venatalk_1082_schema).load("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114526000.txt")

venatalk_1082_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- sem_id: string (nullable = true)
# -- top_cors_id: string (nullable = true)
# -- lv_cd: string (nullable = true)
# -- g_seq: string (nullable = true)
# -- com_id: long (nullable = true)
# -- topic_code: string (nullable = true)
# -- topic_title: string (nullable = true)
# -- study_time: long (nullable = true)
# -- evaluation_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- study_code: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
#     |    |-- element: string (nullable = true)
#     |    |-- data: long (nullable = true)
# ...

# %%
venatalk_1082_DF.show() # 잘 들어왔음을 확인
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----------+-------+----------+------+----------+--------------------+----------+--------------------+--------------------+--------------------+
# sem_id|top_cors_id|  lv_cd|     g_seq|com_id|topic_code|         topic_title|study_time|     evaluation_data|          study_data|             SR_data|
# +------+-----------+-------+----------+------+----------+--------------------+----------+--------------------+--------------------+--------------------+
#    544|        791|Sprout1|1000000073|  1082|TP_SP1A_01|Vaccinations agai...|        35|[[evaluation, 1, ...|[[study, 1, Where...|[[SR, 1, json, [[...|
# ...

# %% [markdown]
# ### 3. VENA Talk 1076 Schema

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

venatalk_1076_schema = StructType([
  StructField("sem_id", StringType(), True),
  StructField("top_cors_id", StringType(), True),
  StructField("lv_cd", StringType(), True),
  StructField("g_seq", StringType(), True),
  StructField("com_id", LongType(), True),
  StructField("topic_code", StringType(), True),
  StructField("topic_title", StringType(), True),
  StructField("study_time", LongType(), True),
  StructField("total_score", LongType(), True),
  StructField("total_star", LongType(), True),
  StructField("evaluation_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", LongType(), True)
                  ]), True
                ), True  
  ),
  StructField("study_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("text_data", StringType(), True),
                    StructField("audio_data", StringType(), True),
                    StructField("is_student", LongType(), True)
                  ]), True), True),
  StructField("SR_data", 
                ArrayType(
                  StructType([
                    StructField("study_code", StringType(), True),
                    StructField("page_order_seq", LongType(), True),
                    StructField("element", StringType(), True),
                    StructField("data", StructType([
                      StructField("analysisResult", StructType([
                          StructField("endTime", StringType(), True),
                          StructField("progressCode", StringType(), True),
                          StructField("reqDataIndex", StringType(), True),
                          StructField("result", StringType(), True),
                          StructField("score", StringType(), True),
                          StructField("startTime", StringType(), True)
                      ]), True),
                      StructField("ticketID", StringType(), True)
                    ]), True)
                  ]), True))
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
venatalk_1076_DF = spark.read.format("json").schema(venatalk_1076_schema).load("./mnt/cdpocmount/april/aistudy_result/544/791/Sprout1/1000000073/1422842_20200309114709000.txt")
venatalk_1076_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- sem_id: string (nullable = true)
# -- top_cors_id: string (nullable = true)
# -- lv_cd: string (nullable = true)
# -- g_seq: string (nullable = true)
# -- com_id: long (nullable = true)
# -- topic_code: string (nullable = true)
# -- topic_title: string (nullable = true)
# -- study_time: long (nullable = true)
# -- total_score: long (nullable = true)
# -- total_star: long (nullable = true)
# -- evaluation_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- study_code: string (nullable = true)
#     |    |-- page_order_seq: long (nullable = true)
# ...

# %%
venatalk_1076_DF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----------+-------+----------+------+----------+--------------------+----------+-----------+----------+--------------------+--------------------+--------------------+
# sem_id|top_cors_id|  lv_cd|     g_seq|com_id|topic_code|         topic_title|study_time|total_score|total_star|     evaluation_data|          study_data|             SR_data|
# +------+-----------+-------+----------+------+----------+--------------------+----------+-----------+----------+--------------------+--------------------+--------------------+
# ...
