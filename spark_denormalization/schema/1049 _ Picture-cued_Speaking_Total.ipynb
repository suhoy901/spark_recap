# %% [markdown]
# ## 1. Picture-cued Speaking infer sample : 1049

# %%
picturecuedSpeaking_infer_DF = spark.read.format("json").option("inferSchema", "true").load("./mnt/cdpocmount/april/study_result/544/791/93669/1049/1422842/1422842_20200309113309000.txt")
picturecuedSpeaking_infer_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- act_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- act_code: string (nullable = true)
#     |    |-- act_name: string (nullable = true)
#     |    |-- act_order_seq: string (nullable = true)
#     |    |-- is_record_api: long (nullable = true)
#     |    |-- page_data: array (nullable = true)
#     |    |    |-- element: struct (containsNull = true)
#     |    |    |    |-- model_answer: string (nullable = true)
#     |    |    |    |-- model_audio: string (nullable = true)
#     |    |    |    |-- model_hint: array (nullable = true)
#     |    |    |    |    |-- element: string (containsNull = true)
#     |    |    |    |-- model_image: string (nullable = true)
#     |    |    |    |-- page_order_seq: string (nullable = true)
#     |    |    |    |-- rec_enable: long (nullable = true)
#     |    |    |    |-- sr_score: long (nullable = true)
#     |    |    |    |-- sr_text: string (nullable = true)
#     |    |    |    |-- std_answer: string (nullable = true)
#     |    |    |    |-- std_audio: string (nullable = true)
#     |    |    |    |-- std_audio_retry_cnt: long (nullable = true)
#     |    |    |    |-- std_audio_time: double (nullable = true)
# -- app_ver: string (nullable = true)
# -- com_id: long (nullable = true)
# -- g_seq: long (nullable = true)
# -- mac_address: string (nullable = true)
# -- manufacturer: string (nullable = true)
# -- model: string (nullable = true)
# -- sem_id: long (nullable = true)
# -- serial: string (nullable = true)
# -- study_time: long (nullable = true)
# -- submit_seq: string (nullable = true)
# -- top_cors_id: long (nullable = true)
#
# </div>

# %%
picturecuedSpeaking_infer_DF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------+------+-----+-----------+------------+-----+------+------+----------+----------+-----------+
#             act_data|app_ver|com_id|g_seq|mac_address|manufacturer|model|sem_id|serial|study_time|submit_seq|top_cors_id|
# +--------------------+-------+------+-----+-----------+------------+-----+------+------+----------+----------+-----------+
# [[APIL_00527, Pre...|       |  1049|93669|           |            |     |   544|      |        76|         1|        791|
# +--------------------+-------+------+-----+-----------+------------+-----+------+------+----------+----------+-----------+
#
# </div>

# %% [markdown]
# ## 2. Picture-cued Speaking Schema

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

picturecuedSpeaking_1049_schema = StructType([
  StructField("sem_id", LongType(), True),
  StructField("top_cors_id", LongType(), True),
  StructField("com_id", LongType(), True),
  StructField("g_seq", LongType(), True),
  StructField("app_ver", StringType(), True),
  StructField("serial", StringType(), True),
  StructField("mac_address", StringType(), True),
  StructField("manufacturer", StringType(), True),
  StructField("model", StringType(), True),
  StructField("submit_seq", StringType(), True),
  StructField("study_time", LongType(), True),
  StructField("act_data", 
                ArrayType(
                  StructType([
                    StructField("act_code", StringType(), True),
                    StructField("act_name", StringType(), True),
                    StructField("act_order_seq", StringType(), True),
                    StructField("is_record_api", LongType(), True),
                    StructField("page_data", ArrayType(
                      StructType([
                        StructField("page_order_seq", StringType(), True),
                        StructField("rec_enable", LongType(), True),
                        StructField("model_answer", StringType(), True),
                        StructField("model_hint", ArrayType(StringType()), True),
                        StructField("model_audio", StringType(), True),
                        StructField("model_image", StringType(), True),
                        StructField("std_answer", StringType(), True),
                        StructField("std_audio", StringType(), True),
                        StructField("std_audio_time", DoubleType(), True),
                        StructField("std_audio_retry_cnt", LongType(), True),
                        StructField("sr_score", LongType(), True),
                        StructField("sr_text", StringType(), True)
                      ]), True
                    ), True),
                  ]), True
                ), True  
  )
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import *


picturecuedSpeaking_DF = spark.read.schema(picturecuedSpeaking_1049_schema).json("./mnt/cdpocmount/april/study_result/544/791/93669/1049/1422842/1422842_20200309113309000.txt")

picturecuedSpeaking_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- sem_id: long (nullable = true)
# -- top_cors_id: long (nullable = true)
# -- com_id: long (nullable = true)
# -- g_seq: long (nullable = true)
# -- app_ver: string (nullable = true)
# -- serial: string (nullable = true)
# -- mac_address: string (nullable = true)
# -- manufacturer: string (nullable = true)
# -- model: string (nullable = true)
# -- submit_seq: string (nullable = true)
# -- study_time: long (nullable = true)
# -- act_data: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- act_code: string (nullable = true)
#     |    |-- act_name: string (nullable = true)
#     |    |-- act_order_seq: string (nullable = true)
#     |    |-- is_record_api: long (nullable = true)
#     |    |-- page_data: array (nullable = true)
#     |    |    |-- element: struct (containsNull = true)
#     |    |    |    |-- page_order_seq: string (nullable = true)
#     |    |    |    |-- rec_enable: long (nullable = true)
#     |    |    |    |-- model_answer: string (nullable = true)
#     |    |    |    |-- model_hint: array (nullable = true)
#     |    |    |    |    |-- element: string (containsNull = true)
#     |    |    |    |-- model_audio: string (nullable = true)
#     |    |    |    |-- model_image: string (nullable = true)
#     |    |    |    |-- std_answer: string (nullable = true)
#     |    |    |    |-- std_audio: string (nullable = true)
#     |    |    |    |-- std_audio_time: double (nullable = true)
#     |    |    |    |-- std_audio_retry_cnt: long (nullable = true)
#     |    |    |    |-- sr_score: long (nullable = true)
#     |    |    |    |-- sr_text: string (nullable = true)
#
# </div>

# %%
display(picturecuedSpeaking_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sem_id</th><th>top_cors_id</th><th>com_id</th><th>g_seq</th><th>app_ver</th><th>serial</th><th>mac_address</th><th>manufacturer</th><th>model</th><th>submit_seq</th><th>study_time</th><th>act_data</th></tr></thead><tbody><tr><td>544</td><td>791</td><td>1049</td><td>93669</td><td></td><td></td><td></td><td></td><td></td><td>1</td><td>76</td><td>List(List(APIL_00527, Present, 2, 1, List(List(1, 1, Miss Jones sneezed <strong>without covering</strong> her mouth. She <strong>wiped her nose</strong> with her hand. The students <strong>were shocked</strong>. She <strong>picked up</strong> a board marker <strong>with her gross hand</strong>. She <strong>wrote</strong> “How to Stay Healthy” <strong>on the board</strong>., List(without covering, wiped her nose, were shocked, picked up, with her gross hand, wrote, on the board), https://ail.chungdahm.com/LCMSFiles/Packing_org/APRILIL/APIL_T01_R/791/Sprout1/APRILIL_791_Sprout1_93669_101/SR1_B1_L1_WK1_PS5.mp3, https://ail.chungdahm.com/LCMSFiles/Packing_org/APRILIL/APIL_T01_R/791/Sprout1/APRILIL_791_Sprout1_93669_101/SR1_B1_L1_WK1_PS_thumb.jpg, Miss Jones sneezed without covering her mouth.<br>She wiped her nose with her hand. The students were shocked.<br>She picked up a board marker with her gross hand.<br>She wrote “How to Stay Healthy” on the board., /study_result/544/791/93669/1049/1422842/1422842_act2_page1_20200309113309010.mp3, 8.699999999999985, 1, 0, null))))</td></tr></tbody></table></div>
