# %%
dbutils.fs.ls("/mnt/cdpocmount/chungdahm/548/619/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>[FileInfo(path=&apos;dbfs:/mnt/cdpocmount/chungdahm/548/619/23720/&apos;, name=&apos;23720/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/cdpocmount/chungdahm/548/619/23721/&apos;, name=&apos;23721/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/cdpocmount/chungdahm/548/619/23722/&apos;, name=&apos;23722/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/cdpocmount/chungdahm/548/619/23723/&apos;, name=&apos;23723/&apos;, size=0),
# ...

# %% [markdown]
# ## 1. read json file
# ### 1.2 Create temp table with json data
#
# target table has 113 column(s) but the inserted data has 116

# %% [markdown]
# #### tip) 정의한 스키마를 적용
#
# ```python
# with open("/dbfs/mnt/cdpocmount/json_schema/chungdahm_619_schema.json") as f:
#     new_schema = StructType.fromJson(json.load(f))
#     print(new_schema.simpleString())
#
#
# # 다시 로드한 재정의가 완료된 스키마를 적용
# chungdahm_619_sample_new_DF = spark.read.schema(new_schema).json("./mnt/cdpocmount/chungdahm/548/619/23720/*/*.json")
# chungdahm_619_sample_new_DF.printSchema()
#
# chungdahm_619_sample_new_DF.createOrReplaceTempView("chungdahm_619_sample_new_DF")
# ```

# %%
# %python 
from pyspark.sql.functions import *
from pyspark.sql.types import *

chungdahm_619_schema = StructType([
  StructField("basePath", StringType(), True),
  StructField("com_id", StringType(), True),
  StructField("componentId", StringType(), True),
  StructField("componentName", StringType(), True),
  StructField("componentType", StringType(), True),
  StructField("created_agent", StringType(), True),
  StructField("created_date", StringType(), True),
  StructField("cssPage", StringType(), True),
  StructField("elapsedTime", LongType(), True),
  StructField("g_seq", StringType(), True),
  StructField("learningReport", StringType(), True),
  StructField("mode", StringType(), True),
  StructField("page", LongType(), True),
  StructField("resultSplitPage", StringType(), True),
  StructField("reviewSplitPage", StringType(), True),
  StructField("sem_id", StringType(), True),
  StructField("setting", StringType(), True),
  StructField("splitPage", StringType(), True),
  StructField("std_id", StringType(), True),
  StructField("studyMode", StringType(), True),
  StructField("tab", LongType(), True),
  StructField("theme", StringType(), True),
  StructField("top_cors_id", StringType(), True),
  StructField("version", StringType(), True),
  StructField("studyData", 
              StructType([
                StructField("draft", StructType([
                  StructField("content", StringType(), True),
                  StructField("contentObj", StringType(), True),
                  StructField("draftVersion", LongType(), True),
                  StructField("ginger_revisionData", ArrayType(
                    StructType([
                      StructField("afterWord", StringType(), True),
                      StructField("beforeWord", StringType(), True),
                      StructField("gCheckAnswer", StringType(), True),
                      StructField("gSelectType", StringType(), True),
                      StructField("revisionReplaceWord", StringType(), True),
                      StructField("tcidx", LongType(), True),
                    ]), True
                  ), True),
                  StructField("ginger_revisionText", StringType(), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("isProofreading", BooleanType(), True),
                  StructField("promptDifficulty", StringType(), True),
                  StructField("styledContent", StringType(), True),
                  StructField("suggestCnt", LongType(), True),
                  StructField("suggestions", ArrayType(
                    ArrayType(
                      StructType([
                        StructField("accepted", BooleanType(), True),
                        StructField("after", StringType(), True),
                        StructField("before", StringType(), True),
                        StructField("beforeWordLength", LongType(), True),
                        StructField("from", LongType(), True),
                        StructField("id", LongType(), True),
                        StructField("idx", LongType(), True),
                        StructField("tcidx", LongType(), True),
                        StructField("title", StringType(), True),
                        StructField("to", LongType(), True),
                        StructField("topLrnCatId", LongType(), True),
                        StructField("type", LongType(), True),
                      ]), True
                    ), True
                  ), True),
                  StructField("title", StringType(), True),
                  StructField("titleObj", StringType(), True),
                  StructField("wordCount", LongType(), True),
                ]), True),
                StructField("gCheckEditing", StructType([
                  StructField("content", StringType(), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("title", StringType(), True),
                ]), True),
                StructField("image", StructType([
                  StructField("imageChangeCnt", LongType(), True),
                  StructField("images", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("isProgressed", BooleanType(), True),
                ]), True),
                StructField("layout", StructType([
                  StructField("bgType", StringType(), True),
                  StructField("imageChangeCnt", LongType(), True),
                  StructField("images", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("isPositionBtnActive", ArrayType(
                    BooleanType(), True
                  ), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("positions", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("selectedParagraphIdxs", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("studyData", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("writingHTML", StringType(), True),
                ]), True),
                StructField("layoutReview", StructType([
                  StructField("bgType", StringType(), True),
                  StructField("images", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("positions", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("selectedParagraphIdxs", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("studyData", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("writingHTML", StringType(), True),
                ]), True),
                StructField("sCheck", StructType([
                  StructField("checkedErrors", ArrayType(
                    BooleanType(), True
                  ), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("sCheckErrorCnt", LongType(), True),
                ]), True),
                StructField("sCheckEditing", StructType([
                  StructField("content", StringType(), True),
                  StructField("contentObj", StringType(), True),
                  StructField("ginger_revisionData", ArrayType(
                    StructType([
                      StructField("afterWord", StringType(), True),
                      StructField("beforeWord", StringType(), True),
                      StructField("gCheckAnswer", StringType(), True),
                      StructField("gSelectType", StringType(), True),
                      StructField("revisionReplaceWord", StringType(), True),
                      StructField("tcidx", LongType(), True),
                    ]), True
                  ), True),
                  StructField("ginger_revisionText", StringType(), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("styledContent", StringType(), True),
                  StructField("suggestCnt", LongType(), True),
                  StructField("suggestions", ArrayType(
                    ArrayType(
                      StructType([
                        StructField("accepted", BooleanType(), True),
                        StructField("after", StringType(), True),
                        StructField("before", StringType(), True),
                        StructField("beforeWordLength", LongType(), True),
                        StructField("from", LongType(), True),
                        StructField("id", LongType(), True),
                        StructField("idx", LongType(), True),
                        StructField("tcidx", LongType(), True),
                        StructField("title", StringType(), True),
                        StructField("to", LongType(), True),
                        StructField("topLrnCatId", LongType(), True),
                        StructField("type", LongType(), True)
                      ]), True
                    ), True
                  ), True),
                  StructField("title", StringType(), True),
                  StructField("titleObj", StringType(), True),
                  StructField("wordCount", StringType(), True),
                ]), True),
                StructField("tip", StructType([
                  StructField("isProgressed", BooleanType(), True),
                  ]), True
                ),
                StructField("warmUp", StructType([
                  StructField("correctAnswers", ArrayType(
                    StringType(), True
                   ), True),
                  StructField("isConfirm", BooleanType(), True),
                  StructField("isProgressed", BooleanType(), True),
                  StructField("userAnswers", ArrayType(
                    StringType(), True
                  ), True),
                  StructField("warmUpData", ArrayType(
                    StructType([
                      StructField("gradeYN", StringType(), True),
                      StructField("page_order", StringType(), True),
                      StructField("sentence", StringType(), True),
                      StructField("sentence_answer", StringType(), True),
                    ]), True
                  ), True) 
                ]), True       
                )
            ]),True
              
  )
])

chungdahm_619_DF = spark.read.format("json").schema(chungdahm_619_schema).load("./mnt/cdpocmount/chungdahm/548/619/23720/*/*.json")
chungdahm_619_DF.createOrReplaceTempView("chungdahm_619_temp")
#venatalk_1076_DF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#chungdahm_619_DF = spark.read.format("json").option("mode", "FAILFAST").option("inferSchema", "true").load("./mnt/cdpocmount/chungdahm/548/619/23720/*/*.json")
#chungdahm_619_DF.printSchema()

# %% [markdown]
# basePath, com_id, componentId, componentName, componentType, created_agent, created_date, cssPage, elapsedTime, g_seq, learningReport, mode, page, resultSplitPage, reviewSplitPage, sem_id, setting, splitPage, std_id, studyData, studyMode, tab, theme, top_cors_id, version

# %%
# %sql

select count(*) from chungdahm_619_temp

# %%
# %sql

describe chungdahm_619_temp

# %%
# %sql
drop table chungdahm_619_prod

# %%
# %sql
-- Product table 생성 (없을 경우 생성 )
create table IF NOT EXISTS chungdahm_619_prod(
basePath string 
,com_id bigint
,componentId string
,componentName string
,componentType string
,created_agent string	
,created_date string
,cssPage string	
,elapsedTime bigint	
,g_seq string	
,learningReport string
,mode string
,page bigint
,resultSplitPage string  
,reviewSplitPage string
,sem_id string 
,setting string
,splitPage string
,std_id string
,studyMode string
,tab bigint
,thema string
,top_cors_id string
,version string

,studyData_warmup_useranswers string
,studyData_warmup_correctanswers string
,studyData_warmup_warmupdata_gradeYN string
,studyData_warmup_warmupdata_sentence_answer string
,studyData_warmup_warmupdata_sentence string
,studyData_warmup_warmupdata_page_order string
,studyData_warmUp_isProgressed boolean
,studyData_warmUp_isConfirm boolean

,studyData_tip_isProgressed boolean

,studyData_draft_title string
,studyData_draft_content string
,studyData_draft_wordCount bigint
,studyData_draft_isProofreading boolean
,studyData_draft_promptDifficulty string
,studyData_draft_isProgressed boolean
,studyData_draft_draftVersion bigint

,studyData_draft_ginger_revisionText string
,studyData_draft_ginerrevisiondata_tcidx bigint
,studyData_draft_ginerrevisiondata_revisionReplaceWord string
,studyData_draft_ginerrevisiondata_gCheckAnswer string
,studyData_draft_ginerrevisiondata_gSelectType string
,studyData_draft_ginerrevisiondata_beforeWord string
,studyData_draft_ginerrevisiondata_afterWord string

,studyData_draft_styledContent string

,studyData_draft_titleObj string

,studyData_draft_contentObj string

,studyData_draft_suggestions_2_from bigint
,studyData_draft_suggestions_2_to bigint
,studyData_draft_suggestions_2_before string
,studyData_draft_suggestions_2_beforeWordLength bigint
,studyData_draft_suggestions_2_after string
,studyData_draft_suggestions_2_accepted boolean
,studyData_draft_suggestions_2_topLrnCatId bigint
,studyData_draft_suggestions_2_type bigint
,studyData_draft_suggestions_2_id bigint
,studyData_draft_suggestions_2_idx bigint
,studyData_draft_suggestions_2_title string
,studyData_draft_suggestions_2_tcidx bigint

,studyData_draft_suggestCnt bigint

,studyData_image_images string
,studyData_image_imageChangeCnt bigint
,studyData_image_isProgressed boolean

,studyData_layout_studyData string
,studyData_layout_images string
,studyData_layout_imageChangeCnt bigint
,studyData_layout_bgType string
,studyData_layout_positions string
,studyData_layout_selectedParagraphIdxs string
,studyData_layout_writingHTML string
,studyData_layout_isPositionBtnActive boolean
,studyData_layout_isProgressed boolean

,studyData_sCheck_sCheckErrorCnt bigint
,studyData_sCheck_checkedErrors boolean
,studyData_sCheck_isProgressed boolean

,studyData_gCheckEditing_title string
,studyData_gCheckEditing_content string
,studyData_gCheckEditing_isProgressed boolean

,studyData_sCheckEditing_title string
,studyData_sCheckEditing_content string
,studyData_sCheckEditing_wordCount bigint
,studyData_sCheckEditing_isProgressed boolean

,studyData_sCheckEditing_suggestions_2_from bigint
,studyData_sCheckEditing_suggestions_2_to bigint
,studyData_sCheckEditing_suggestions_2_before string
,studyData_sCheckEditing_suggestions_2_beforeWordLength bigint
,studyData_sCheckEditing_suggestions_2_after string
,studyData_sCheckEditing_suggestions_2_accepted boolean
,studyData_sCheckEditing_suggestions_2_topLrnCatId bigint
,studyData_sCheckEditing_suggestions_2_type bigint
,studyData_sCheckEditing_suggestions_2_id bigint
,studyData_sCheckEditing_suggestions_2_idx bigint
,studyData_sCheckEditing_suggestions_2_title string
,studyData_sCheckEditing_suggestions_2_tcidx bigint

,studyData_sCheckEditing_suggestCnt bigint

,studyData_sCheckEditing_ginger_revisionText string
,studyData_sCheckEditing_gingerrevisionData_tcidx bigint
,studyData_sCheckEditing_gingerrevisionData_revisionReplaceWord string
,studyData_sCheckEditing_gingerrevisionData_gCheckAnswer string
,studyData_sCheckEditing_gingerrevisionData_gSelectType string
,studyData_sCheckEditing_gingerrevisionData_beforeWord string
,studyData_sCheckEditing_gingerrevisionData_afterWord string

,studyData_sCheckEditing_styledContent string
,studyData_sCheckEditing_titleObj string
,studyData_sCheckEditing_contentObj string

,studyData_layoutReview_studyData string
,studyData_layoutReview_images string
,studyData_layoutReview_bgType string
,studyData_layoutReview_positions string
,studyData_layoutReview_selectedParagraphIdxs string
,studyData_layoutReview_writingHTML string
,studyData_layoutReview_isProgressed boolean
)
USING DELTA
  LOCATION '/mnt/cdpocmount/delta/chungdahm_619_prod'

# %%
# %sql
describe chungdahm_619_prod

# %%
# %sql
--- 116
insert into chungdahm_619_prod
select 
basePath
, com_id
, componentId
, componentName
, componentType
, created_agent
, created_date
, cssPage
, elapsedTime
, g_seq
, learningReport
, mode
, page
, resultSplitPage
, reviewSplitPage
, sem_id
, setting
, splitPage
, std_id
, studyMode
, tab
, theme
, top_cors_id
, version,

-- 1. studyData : warmUp
--studyData.warmUp,
studyData_warmup_useranswers,
studyData_warmup_correctanswers,
studyData_warmup_warmupdata.gradeYN,
studyData_warmup_warmupdata.sentence_answer,
studyData_warmup_warmupdata.sentence,
studyData_warmup_warmupdata.page_order,
studyData.warmUp.isProgressed,
studyData.warmUp.isConfirm,


-- studyData : tip
studyData.tip.isProgressed,

-- studyData : draft
--studyData.draft,
studyData.draft.title,
studyData.draft.content,
studyData.draft.wordCount,
studyData.draft.isProofreading,
studyData.draft.promptDifficulty,
studyData.draft.isProgressed,
studyData.draft.draftVersion,

studyData.draft.ginger_revisionText,
studyData_draft_ginerrevisiondata_tcidx,
studyData_draft_ginerrevisiondata_revisionReplaceWord,
studyData_draft_ginerrevisiondata_gCheckAnswer,
studyData_draft_ginerrevisiondata_gSelectType,
studyData_draft_ginerrevisiondata_beforeWord,
studyData_draft_ginerrevisiondata_afterWord,

studyData.draft.styledContent,

studyData.draft.titleObj, 

studyData.draft.contentObj, 

studyData_draft_suggestions_2.from,
studyData_draft_suggestions_2.to,
studyData_draft_suggestions_2.before,
studyData_draft_suggestions_2.beforeWordLength,
studyData_draft_suggestions_2.after,
studyData_draft_suggestions_2.accepted,
studyData_draft_suggestions_2.topLrnCatId,
studyData_draft_suggestions_2.type,
studyData_draft_suggestions_2.id,
studyData_draft_suggestions_2.idx,
studyData_draft_suggestions_2.title,
studyData_draft_suggestions_2.tcidx,

studyData.draft.suggestCnt,


studyData_image_images,
studyData.image.imageChangeCnt,
studyData.image.isProgressed,



studyData_layout_studyData,
studyData_layout_images,
studyData.layout.imageChangeCnt,
studyData.layout.bgType,
studyData_layout_positions,
studyData_layout_selectedParagraphIdxs,
studyData.layout.writingHTML,
studyData_layout_isPositionBtnActive,
studyData.layout.isProgressed,

studyData.sCheck.sCheckErrorCnt,
studyData_sCheck_checkedErrors,
studyData.sCheck.isProgressed,


studyData.gCheckEditing.title,
studyData.gCheckEditing.content,
studyData.gCheckEditing.isProgressed,

studyData.sCheckEditing.title,
studyData.sCheckEditing.content,
studyData.sCheckEditing.wordCount,
studyData.sCheckEditing.isProgressed,

studyData_sCheckEditing_suggestions_2.from,
studyData_sCheckEditing_suggestions_2.to,
studyData_sCheckEditing_suggestions_2.before,
studyData_sCheckEditing_suggestions_2.beforeWordLength,
studyData_sCheckEditing_suggestions_2.after,
studyData_sCheckEditing_suggestions_2.accepted,
studyData_sCheckEditing_suggestions_2.topLrnCatId,
studyData_sCheckEditing_suggestions_2.type,
studyData_sCheckEditing_suggestions_2.id,
studyData_sCheckEditing_suggestions_2.idx,
studyData_sCheckEditing_suggestions_2.title,
studyData_sCheckEditing_suggestions_2.tcidx,

studyData.sCheckEditing.suggestCnt,

studyData.sCheckEditing.ginger_revisionText,
studyData_sCheckEditing_gingerrevisionData.tcidx,
studyData_sCheckEditing_gingerrevisionData.revisionReplaceWord,
studyData_sCheckEditing_gingerrevisionData.gCheckAnswer,
studyData_sCheckEditing_gingerrevisionData.gSelectType,
studyData_sCheckEditing_gingerrevisionData.beforeWord,
studyData_sCheckEditing_gingerrevisionData.afterWord,

studyData.sCheckEditing.styledContent, 
studyData.sCheckEditing.titleObj,
studyData.sCheckEditing.contentObj, 


studyData_layoutReview_studyData,
studyData_layoutReview_images, 
studyData.layoutReview.bgType,
studyData_layoutReview_positions,
studyData_layoutReview_selectedParagraphIdxs,
studyData.layoutReview.writingHTML,
studyData.layoutReview.isProgressed

from chungdahm_619_temp


lateral view explode(studyData.warmUp.userAnswers) studyData_warmup_useranswers as studyData_warmup_useranswers
lateral view explode(studyData.warmUp.correctAnswers) studyData_warmup_correctanswers as studyData_warmup_correctanswers
lateral view explode(studyData.warmUp.warmUpData) studyData_warmup_warmupdata as studyData_warmup_warmupdata

lateral view explode(studyData.draft.ginger_revisionData) studyData_draft_ginerrevisiondata as studyData_draft_ginerrevisiondata
lateral view explode(studyData.draft.ginger_revisionData.tcidx) studyData_draft_ginerrevisiondata_tcidx as studyData_draft_ginerrevisiondata_tcidx
lateral view explode(studyData.draft.ginger_revisionData.revisionReplaceWord) studyData_draft_ginerrevisiondata_revisionReplaceWord
 as studyData_draft_ginerrevisiondata_revisionReplaceWord

lateral view explode(studyData.draft.ginger_revisionData.gCheckAnswer) studyData_draft_ginerrevisiondata_gCheckAnswer
 as studyData_draft_ginerrevisiondata_gCheckAnswer

lateral view explode(studyData.draft.ginger_revisionData.gSelectType) studyData_draft_ginerrevisiondata_gSelectType
 as studyData_draft_ginerrevisiondata_gSelectType

lateral view explode(studyData.draft.ginger_revisionData.beforeWord) studyData_draft_ginerrevisiondata_beforeWord
 as studyData_draft_ginerrevisiondata_beforeWord

lateral view explode(studyData.draft.ginger_revisionData.afterWord) studyData_draft_ginerrevisiondata_afterWord
 as studyData_draft_ginerrevisiondata_afterWord


lateral view explode(studyData.draft.suggestions) studyData_draft_suggestions as studyData_draft_suggestions
lateral view explode(studyData_draft_suggestions) studyData_draft_suggestions_2 as studyData_draft_suggestions_2

lateral view explode(studyData.image.images) studyData_image_images as studyData_image_images

lateral view explode(studyData.layout.studyData) studyData_layout_studyData as studyData_layout_studyData
lateral view explode(studyData.layout.images) studyData_layout_images as studyData_layout_images
lateral view explode(studyData.layout.positions) studyData_layout_positions as studyData_layout_positions
lateral view explode(studyData.layout.selectedParagraphIdxs) studyData_layout_selectedParagraphIdxs as studyData_layout_selectedParagraphIdxs
lateral view explode(studyData.layout.isPositionBtnActive) studyData_layout_isPositionBtnActive as studyData_layout_isPositionBtnActive

lateral view explode(studyData.sCheck.checkedErrors) studyData_sCheck_checkedErrors as studyData_sCheck_checkedErrors

lateral view explode(studyData.sCheckEditing.suggestions) studyData_sCheckEditing_suggestions as studyData_sCheckEditing_suggestions
lateral view explode(studyData_sCheckEditing_suggestions) studyData_sCheckEditing_suggestions_2 as studyData_sCheckEditing_suggestions_2
lateral view explode(studyData.sCheckEditing.ginger_revisionData) studyData_sCheckEditing_gingerrevisionData as studyData_sCheckEditing_gingerrevisionData


lateral view explode(studyData.layoutReview.studyData) studyData_layoutReview_studyData as studyData_layoutReview_studyData
lateral view explode(studyData.layoutReview.images) studyData_layoutReview_images as studyData_layoutReview_images
lateral view explode(studyData.layoutReview.positions) studyData_layoutReview_positions as studyData_layoutReview_positions
lateral view explode(studyData.layoutReview.selectedParagraphIdxs) studyData_layoutReview_selectedParagraphIdxs as studyData_layoutReview_selectedParagraphIdxs
