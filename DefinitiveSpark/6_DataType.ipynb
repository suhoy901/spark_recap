# %%
from pyspark.sql import SparkSession

spark = SparkSession \
  .builder \
  .appName("python spark sql basic example") \
  .config("spark.some.config.option", "some-value") \
  .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Chapter 6. 다양한 데이터 타입 다루기
# ## 6.1 API는 어디서 찾을까?
# - DataFrame 메서드
#   - DataFrameStatFunctions : 다양한 통계적 함수를 제공
#   - DataFrameNaFunctions : null 데이터를 다루는데 필요한 함수를 제공
# - Column 메서드
#   - alias, contain과 같은 컬럼과 관련된 여러가지 메서드를 제공
#   - org.apache.spark.sql.function 패키지는 데이터 타입과 관련된 다양한 함수를 제공

# %%
# DataFrame 생성
df = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("./FileStore/tables/data/retail-data/by-day/2010_12_01-ec65d.csv")

df.printSchema()
df.createOrReplaceTempView("dfTable")
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536365</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>2.55</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84406B</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>2010-12-01T08:26:00.000+0000</td><td>2.75</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029G</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029E</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.2 스파크 데이터 타입으로 변환하기
# - lit 함수 : 다른 언어의 데이터 타입을 스파크 데이터 타입에 맞게 변환
# - sparkSQL에서는 스파크 데이터 타입으로 변경할 수 없음

# %%
# 스파크 데이터 타입으로 변환
from pyspark.sql.functions import lit

display(df.select(lit(5), lit("five"), lit(5.0)).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>5</th><th>five</th><th>5.0</th></tr></thead><tbody><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr><tr><td>5</td><td>five</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.3 불리언 데이터 타입 다루기

# %%
from pyspark.sql.functions import col

display(df.where(col("InvoiceNo") != 536365) \
  .select("InvoiceNo", "Description").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>Description</th></tr></thead><tbody><tr><td>536366</td><td>HAND WARMER UNION JACK</td></tr><tr><td>536366</td><td>HAND WARMER RED POLKA DOT</td></tr><tr><td>536367</td><td>ASSORTED COLOUR BIRD ORNAMENT</td></tr><tr><td>536367</td><td>POPPY'S PLAYHOUSE BEDROOM </td></tr><tr><td>536367</td><td>POPPY'S PLAYHOUSE KITCHEN</td></tr><tr><td>536367</td><td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td></tr><tr><td>536367</td><td>IVORY KNITTED MUG COSY </td></tr><tr><td>536367</td><td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td></tr><tr><td>536367</td><td>BOX OF VINTAGE JIGSAW BLOCKS </td></tr><tr><td>536367</td><td>BOX OF VINTAGE ALPHABET BLOCKS</td></tr><tr><td>536367</td><td>HOME BUILDING BLOCK WORD</td></tr><tr><td>536367</td><td>LOVE BUILDING BLOCK WORD</td></tr><tr><td>536367</td><td>RECIPE BOX WITH METAL HEART</td></tr><tr><td>536367</td><td>DOORMAT NEW ENGLAND</td></tr><tr><td>536368</td><td>JAM MAKING SET WITH JARS</td></tr><tr><td>536368</td><td>RED COAT RACK PARIS FASHION</td></tr><tr><td>536368</td><td>YELLOW COAT RACK PARIS FASHION</td></tr><tr><td>536368</td><td>BLUE COAT RACK PARIS FASHION</td></tr><tr><td>536369</td><td>BATH BUILDING BLOCK WORD</td></tr><tr><td>536370</td><td>ALARM CLOCK BAKELIKE PINK</td></tr></tbody></table></div>

# %%
display(df.where("InvoiceNo = 536365"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536365</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>2.55</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84406B</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>2010-12-01T08:26:00.000+0000</td><td>2.75</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029G</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029E</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>22752</td><td>SET 7 BABUSHKA NESTING BOXES</td><td>2</td><td>2010-12-01T08:26:00.000+0000</td><td>7.65</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>21730</td><td>GLASS STAR FROSTED T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>4.25</td><td>17850.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %%
display(df.where("InvoiceNo <> 536365").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536366</td><td>22633</td><td>HAND WARMER UNION JACK</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22632</td><td>HAND WARMER RED POLKA DOT</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84879</td><td>ASSORTED COLOUR BIRD ORNAMENT</td><td>32</td><td>2010-12-01T08:34:00.000+0000</td><td>1.69</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22745</td><td>POPPY'S PLAYHOUSE BEDROOM </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22748</td><td>POPPY'S PLAYHOUSE KITCHEN</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22749</td><td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td><td>8</td><td>2010-12-01T08:34:00.000+0000</td><td>3.75</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22310</td><td>IVORY KNITTED MUG COSY </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>1.65</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84969</td><td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>4.25</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22623</td><td>BOX OF VINTAGE JIGSAW BLOCKS </td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22622</td><td>BOX OF VINTAGE ALPHABET BLOCKS</td><td>2</td><td>2010-12-01T08:34:00.000+0000</td><td>9.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21754</td><td>HOME BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21755</td><td>LOVE BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21777</td><td>RECIPE BOX WITH METAL HEART</td><td>4</td><td>2010-12-01T08:34:00.000+0000</td><td>7.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>48187</td><td>DOORMAT NEW ENGLAND</td><td>4</td><td>2010-12-01T08:34:00.000+0000</td><td>7.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22960</td><td>JAM MAKING SET WITH JARS</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>4.25</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22913</td><td>RED COAT RACK PARIS FASHION</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22912</td><td>YELLOW COAT RACK PARIS FASHION</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22914</td><td>BLUE COAT RACK PARIS FASHION</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536369</td><td>21756</td><td>BATH BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:35:00.000+0000</td><td>5.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536370</td><td>22728</td><td>ALARM CLOCK BAKELIKE PINK</td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>3.75</td><td>12583.0</td><td>France</td></tr></tbody></table></div>

# %%
""" an, or 사용한 불리언 표현식 """

from pyspark.sql.functions import instr

priceFilter = col("UnitPrice") > 600
descripFilter = instr(df.Description, "POSTAGE") >= 1 # Locate the position of the first occurrence of substr column in the given string.
                                                      # Returns null if either of the arguments are null.
display(df.where(df.StockCode.isin("DOT")).where(priceFilter | descripFilter))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536544</td><td>DOT</td><td>DOTCOM POSTAGE</td><td>1</td><td>2010-12-01T14:32:00.000+0000</td><td>569.77</td><td>null</td><td>United Kingdom</td></tr><tr><td>536592</td><td>DOT</td><td>DOTCOM POSTAGE</td><td>1</td><td>2010-12-01T17:06:00.000+0000</td><td>607.49</td><td>null</td><td>United Kingdom</td></tr></tbody></table></div>

# %%
""" instr 함수 """

display(df.withColumn("added", instr(df.Description, "POSTAGE")).where("added > 1")) # 8번째 글자에 'POSTAGE'가 시작됨
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th><th>added</th></tr></thead><tbody><tr><td>536544</td><td>DOT</td><td>DOTCOM POSTAGE</td><td>1</td><td>2010-12-01T14:32:00.000+0000</td><td>569.77</td><td>null</td><td>United Kingdom</td><td>8</td></tr><tr><td>536592</td><td>DOT</td><td>DOTCOM POSTAGE</td><td>1</td><td>2010-12-01T17:06:00.000+0000</td><td>607.49</td><td>null</td><td>United Kingdom</td><td>8</td></tr></tbody></table></div>

# %%
# 불리언 컬럼

DOTCodeFilter = col("StockCode") == "DOT"
priceFilter = col("UnitPrice") > 600
descripFilter = instr(col("Description"), "POSTAGE") > 1 # 'POSTAGE' 글자가 첫번째가 아닌 경우

display(df.withColumn("isExpensive", DOTCodeFilter & (priceFilter | descripFilter)) \
  .where("isExpensive") \
  .select("unitPrice", "isExpensive"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>unitPrice</th><th>isExpensive</th></tr></thead><tbody><tr><td>569.77</td><td>true</td></tr><tr><td>607.49</td><td>true</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import expr, col # 파이썬은 not이 존재하지 않음

display(df.withColumn("isExpensive", expr("NOT UnitPrice <= 250")) \
  .where("isExpensive") \
  .select("Description", "UnitPrice"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th><th>UnitPrice</th></tr></thead><tbody><tr><td>DOTCOM POSTAGE</td><td>569.77</td></tr><tr><td>DOTCOM POSTAGE</td><td>607.49</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.4 수치형 데이터 타입 다루기

# %%
from pyspark.sql.functions import expr, pow

fabricateQuantity = pow(col("Quantity") * col("UnitPrice"), 2) + 5
display(df.select(expr("CustomerID"), fabricateQuantity.alias("realQuantity")).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>realQuantity</th></tr></thead><tbody><tr><td>17850.0</td><td>239.08999999999997</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>489.0</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>239.09000000000003</td></tr><tr><td>17850.0</td><td>655.25</td></tr><tr><td>17850.0</td><td>128.21000000000004</td></tr><tr><td>17850.0</td><td>128.21000000000004</td></tr><tr><td>13047.0</td><td>2929.6463999999996</td></tr><tr><td>13047.0</td><td>163.76000000000005</td></tr><tr><td>13047.0</td><td>163.76000000000005</td></tr><tr><td>13047.0</td><td>905.0</td></tr><tr><td>13047.0</td><td>103.00999999999998</td></tr><tr><td>13047.0</td><td>655.25</td></tr><tr><td>13047.0</td><td>225.52250000000004</td></tr><tr><td>13047.0</td><td>401.00999999999993</td></tr><tr><td>13047.0</td><td>323.62250000000006</td></tr><tr><td>13047.0</td><td>323.62250000000006</td></tr><tr><td>13047.0</td><td>1016.24</td></tr></tbody></table></div>

# %%
# SQL문으로 위와 동일한 결과를 실행해보자
display(df.selectExpr(
  "CustomerID",
  "(POWER(Quantity * UnitPrice, 2.0) + 5) as realQuantity"
).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>realQuantity</th></tr></thead><tbody><tr><td>17850.0</td><td>239.08999999999997</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>489.0</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>418.7156</td></tr><tr><td>17850.0</td><td>239.09000000000003</td></tr><tr><td>17850.0</td><td>655.25</td></tr><tr><td>17850.0</td><td>128.21000000000004</td></tr><tr><td>17850.0</td><td>128.21000000000004</td></tr><tr><td>13047.0</td><td>2929.6463999999996</td></tr><tr><td>13047.0</td><td>163.76000000000005</td></tr><tr><td>13047.0</td><td>163.76000000000005</td></tr><tr><td>13047.0</td><td>905.0</td></tr><tr><td>13047.0</td><td>103.00999999999998</td></tr><tr><td>13047.0</td><td>655.25</td></tr><tr><td>13047.0</td><td>225.52250000000004</td></tr><tr><td>13047.0</td><td>401.00999999999993</td></tr><tr><td>13047.0</td><td>323.62250000000006</td></tr><tr><td>13047.0</td><td>323.62250000000006</td></tr><tr><td>13047.0</td><td>1016.24</td></tr></tbody></table></div>

# %%
# 반올림하는 round 함수
from pyspark.sql.functions import lit, round, bround # round(반올림), bround(반내림)

display(df.select(round(lit("2.5"), 1), bround(lit("2.5"), 1)).limit(20)) # 1차원
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>round(2.5, 1)</th><th>bround(2.5, 1)</th></tr></thead><tbody><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr><tr><td>2.5</td><td>2.5</td></tr></tbody></table></div>

# %%
# 피어슨 상관계수 계싼
from pyspark.sql.functions import corr

df.stat.corr("Quantity", "UnitPrice")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: -0.04112314436835551</div>

# %%
# 기술통계 계산
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>count</td><td>3108</td><td>3108</td><td>3098</td><td>3108</td><td>3108</td><td>1968</td><td>3108</td></tr><tr><td>mean</td><td>536516.684944841</td><td>27834.304044117645</td><td>null</td><td>8.627413127413128</td><td>4.151946589446603</td><td>15661.388719512195</td><td>null</td></tr><tr><td>stddev</td><td>72.89447869788873</td><td>17407.897548583845</td><td>null</td><td>26.371821677029203</td><td>15.638659854603892</td><td>1854.4496996893627</td><td>null</td></tr><tr><td>min</td><td>536365</td><td>10002</td><td> 4 PURPLE FLOCK DINNER CANDLES</td><td>-24</td><td>0.0</td><td>12431.0</td><td>Australia</td></tr><tr><td>max</td><td>C536548</td><td>POST</td><td>ZINC WILLIE WINKIE  CANDLE STICK</td><td>600</td><td>607.49</td><td>18229.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %%
display(df.describe("InvoiceNo"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>InvoiceNo</th></tr></thead><tbody><tr><td>count</td><td>3108</td></tr><tr><td>mean</td><td>536516.684944841</td></tr><tr><td>stddev</td><td>72.89447869788873</td></tr><tr><td>min</td><td>536365</td></tr><tr><td>max</td><td>C536548</td></tr></tbody></table></div>

# %%
# 백분위수를 구하는 approxQuantile
quantileProbs = [0.5]
relError = 0.05  # 0일 경우 완전한 분위수를 구하고 시간이 오래걸림

df.stat.approxQuantile("UnitPrice", quantileProbs, relError)
# :relError: The relative target precision to achieve
#   (>= 0). If set to zero, the exact quantiles are computed, which
#   could be very expensive. Note that values greater than 1 are
#   accepted but give the same result as 1.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [2.51]</div>

# %%
# 교차표를 생성하는 crosstab
display(df.select("StockCode").distinct().limit(20)) # row name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>StockCode</th></tr></thead><tbody><tr><td>22728</td></tr><tr><td>21889</td></tr><tr><td>90210B</td></tr><tr><td>21259</td></tr><tr><td>21894</td></tr><tr><td>21452</td></tr><tr><td>22121</td></tr><tr><td>90022</td></tr><tr><td>21249</td></tr><tr><td>21711</td></tr><tr><td>22130</td></tr><tr><td>22314</td></tr><tr><td>21671</td></tr><tr><td>22629</td></tr><tr><td>82486</td></tr><tr><td>22438</td></tr><tr><td>22529</td></tr><tr><td>10133</td></tr><tr><td>21967</td></tr><tr><td>85064</td></tr></tbody></table></div>

# %%
display(df.select("Quantity").distinct().limit(20)) # column name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Quantity</th></tr></thead><tbody><tr><td>34</td></tr><tr><td>-1</td></tr><tr><td>28</td></tr><tr><td>27</td></tr><tr><td>384</td></tr><tr><td>-10</td></tr><tr><td>192</td></tr><tr><td>12</td></tr><tr><td>128</td></tr><tr><td>22</td></tr><tr><td>47</td></tr><tr><td>1</td></tr><tr><td>13</td></tr><tr><td>6</td></tr><tr><td>16</td></tr><tr><td>3</td></tr><tr><td>20</td></tr><tr><td>40</td></tr><tr><td>-7</td></tr><tr><td>432</td></tr></tbody></table></div>

# %%
display(df.stat.crosstab("StockCode", "Quantity").limit(20)) # pivot
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>StockCode_Quantity</th><th>-1</th><th>-10</th><th>-12</th><th>-2</th><th>-24</th><th>-3</th><th>-4</th><th>-5</th><th>-6</th><th>-7</th><th>1</th><th>10</th><th>100</th><th>11</th><th>12</th><th>120</th><th>128</th><th>13</th><th>14</th><th>144</th><th>15</th><th>16</th><th>17</th><th>18</th><th>19</th><th>192</th><th>2</th><th>20</th><th>200</th><th>21</th><th>216</th><th>22</th><th>23</th><th>24</th><th>25</th><th>252</th><th>27</th><th>28</th><th>288</th><th>3</th><th>30</th><th>32</th><th>33</th><th>34</th><th>36</th><th>384</th><th>4</th><th>40</th><th>432</th><th>47</th><th>48</th><th>480</th><th>5</th><th>50</th><th>56</th><th>6</th><th>60</th><th>600</th><th>64</th><th>7</th><th>70</th><th>72</th><th>8</th><th>80</th><th>9</th><th>96</th></tr></thead><tbody><tr><td>22578</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>21327</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>22064</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>21080</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td></tr><tr><td>22219</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0 ...

# %%
# 고유 아이디를 생성하는 monotonically_increasing_id
from pyspark.sql.functions import monotonically_increasing_id

display(df.select(monotonically_increasing_id()).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>monotonically_increasing_id()</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>9</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.5 문자열 데이터 타입 다루기
# - initcap
# - lower, upper
# - llit, ltrim, rtrim, rpad, lpad, trim
# - 정규표현식
#   - regexp_extract, regexp_replace
#   - translate : 문자 치환
#   - regexp_extract : 단어 추출
#   - instr : 단어 존재 유무 확인
#   - locate : 인수의 개수가 동적으로 변하는 상황과 문자열의 위치를 찾는 locate함수

# %%
# 공백으로 나뉘는 모든 단어의 첫 글자를 대문자로 변경
# initcapital
from pyspark.sql.functions import initcap

display(df.select(initcap(col("Description"))).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>initcap(Description)</th></tr></thead><tbody><tr><td>White Hanging Heart T-light Holder</td></tr><tr><td>White Metal Lantern</td></tr><tr><td>Cream Cupid Hearts Coat Hanger</td></tr><tr><td>Knitted Union Flag Hot Water Bottle</td></tr><tr><td>Red Woolly Hottie White Heart.</td></tr><tr><td>Set 7 Babushka Nesting Boxes</td></tr><tr><td>Glass Star Frosted T-light Holder</td></tr><tr><td>Hand Warmer Union Jack</td></tr><tr><td>Hand Warmer Red Polka Dot</td></tr><tr><td>Assorted Colour Bird Ornament</td></tr><tr><td>Poppy's Playhouse Bedroom </td></tr><tr><td>Poppy's Playhouse Kitchen</td></tr><tr><td>Feltcraft Princess Charlotte Doll</td></tr><tr><td>Ivory Knitted Mug Cosy </td></tr><tr><td>Box Of 6 Assorted Colour Teaspoons</td></tr><tr><td>Box Of Vintage Jigsaw Blocks </td></tr><tr><td>Box Of Vintage Alphabet Blocks</td></tr><tr><td>Home Building Block Word</td></tr><tr><td>Love Building Block Word</td></tr><tr><td>Recipe Box With Metal Heart</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import lower, upper

display(df.select(col("Description"), lower(col("Description")), upper(col("Description"))).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th><th>lower(Description)</th><th>upper(Description)</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>white hanging heart t-light holder</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>WHITE METAL LANTERN</td><td>white metal lantern</td><td>WHITE METAL LANTERN</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td><td>cream cupid hearts coat hanger</td><td>CREAM CUPID HEARTS COAT HANGER</td></tr><tr><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>knitted union flag hot water bottle</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td></tr><tr><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>red woolly hottie white heart.</td><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr><tr><td>SET 7 BABUSHKA NESTING BOXES</td><td>set 7 babushka nesting boxes</td><td>SET 7 BABUSHKA NESTING BOXES</td></tr><tr><td>GLASS STAR FROSTED T-LIGHT HOLDER</td><td>glass star frosted t-light holder</td><td>GLASS STAR FROSTED T-LIGHT HOLDER</td></tr><tr><td>HAND WARMER UNION JACK</td><td>hand warmer union jack</td><td>HAND WARMER UNION JACK</td></tr><tr><td>HAND WARMER RED POLKA DOT</td><td>hand warmer red polka dot</td><td>HAND WARMER RED POLKA DOT</td></tr><tr><td>ASSORTED COLOUR BIRD ORNAMENT</td><td>assorted colour bird ornament</td><td>ASSORTED COLOUR BIRD ORNAMENT</td></tr></tbody></table></div>

# %%
# 문자열 주변의 공백을 제거
from pyspark.sql.functions import lit, ltrim, rtrim, rpad, lpad, trim

display(df.select(
    ltrim(lit("   HELLO   ")).alias("ltrim"),
    rtrim(lit("   HELLO   ")).alias("rtrim"),
    trim(lit("   HELLO   ")).alias("trim"),
    lpad(lit("HELLO"), 3, " ").alias("lp"),
    rpad(lit("HELLO"), 10, " ").alias("rp")
).limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ltrim</th><th>rtrim</th><th>trim</th><th>lp</th><th>rp</th></tr></thead><tbody><tr><td>HELLO   </td><td>   HELLO</td><td>HELLO</td><td>HEL</td><td>HELLO     </td></tr><tr><td>HELLO   </td><td>   HELLO</td><td>HELLO</td><td>HEL</td><td>HELLO     </td></tr></tbody></table></div>

# %% [markdown]
# ### 6.5.1 정규 표현식
# - 존재 여부를 확인하거나 일치하는 모든 문자열을 치환
# - 정규 표현식을 위해 regexp_extract 함수와 regexp_reaplace함수를 사용

# %%
from pyspark.sql.functions import regexp_replace

# 단어 치환
regex_string = "BLACK|WHITE|GREEN|BLUE"
display(df.select(
  regexp_replace(col("Description"), regex_string, "COLOR").alias("color_replace"),
  col("Description")
).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color_replace</th><th>Description</th></tr></thead><tbody><tr><td>COLOR HANGING HEART T-LIGHT HOLDER</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>COLOR METAL LANTERN</td><td>WHITE METAL LANTERN</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td><td>CREAM CUPID HEARTS COAT HANGER</td></tr><tr><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td></tr><tr><td>RED WOOLLY HOTTIE COLOR HEART.</td><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr></tbody></table></div>

# %% [markdown]
# pyspark.sql.functions.translate
# ```python
# SELECT translate('AaBbCc', 'abc', '123');
#
# > A1B2C3
# ```

# %%
# 문자 치환, translate
from pyspark.sql.functions import translate

display(df.select(translate(col("Description"), "LEET", "12"),
         col("Description")).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>translate(Description, LEET, 12)</th><th>Description</th></tr></thead><tbody><tr><td>WHI2 HANGING H2AR -1IGH HO1D2R</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>WHI2 M2A1 1AN2RN</td><td>WHITE METAL LANTERN</td></tr><tr><td>CR2AM CUPID H2ARS COA HANG2R</td><td>CREAM CUPID HEARTS COAT HANGER</td></tr><tr><td>KNI2D UNION F1AG HO WA2R BO12</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td></tr><tr><td>R2D WOO11Y HOI2 WHI2 H2AR.</td><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr></tbody></table></div>

# %%
# 단어 추출, regexp_extract
from pyspark.sql.functions import regexp_extract

extract_str = "(BLACK|WHITE|GREEN|BLUE)"
display(df.select(
  regexp_extract(col("Description"), extract_str, 1).alias("color_clean"),
  col("Description")
).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color_clean</th><th>Description</th></tr></thead><tbody><tr><td>WHITE</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>WHITE</td><td>WHITE METAL LANTERN</td></tr><tr><td></td><td>CREAM CUPID HEARTS COAT HANGER</td></tr><tr><td></td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td></tr><tr><td>WHITE</td><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr></tbody></table></div>

# %%
# 단어 존재유무, contain
from pyspark.sql.functions import instr

containBlack = instr(col("Description"), "BLACK") > 1
containWhite = instr(col("Description"), "WHITE") > 1

# where("hasSimpleColor")는 True만 리턴
display(df.withColumn("hasSimpleColor", containBlack | containWhite) \
    .where("hasSimpleColor") \
    .select("Description").limit(5)) # show()에서 False함수는 20이상 확인
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th></tr></thead><tbody><tr><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr><tr><td>WOOD 2 DRAWER CABINET WHITE FINISH</td></tr><tr><td>WOOD S/3 CABINET ANT WHITE FINISH</td></tr><tr><td>WOODEN PICTURE FRAME WHITE FINISH</td></tr><tr><td>WOODEN FRAME ANTIQUE WHITE </td></tr></tbody></table></div>

# %% [markdown]
# - spark.sql.functions.locate
#
# ```python
# l = [('sdiblue', 1), ("bicke", 3), ("nible", 4)]
# df1 = spark.createDataFrame(l, ['s', 'k'])
# df1.select(locate('b', df1.s, 1).alias('s')).collect()
#
# > [Row(s=4), Row(s=1), Row(s=3)]
# ```

# %%
# 인수의 개수가 동적으로 변하는 상황과 문자열의 위치를 찾는 locate함수
from pyspark.sql.functions import expr, locate

simple_color = ["black", "white", "red", "green", "blue"]
def color_locator(column, color_string):
  return locate(color_string.upper(), column).cast("boolean").alias("is_" + color_string) # color_strings 단어가 시작되는 문자기준(단어기준X) 위치

selected_cols = [color_locator(df.Description, c) for c in simple_color]
selected_cols
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [Column&lt;b&#39;CAST(locate(BLACK, Description, 1) AS BOOLEAN) AS `is_black`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(WHITE, Description, 1) AS BOOLEAN) AS `is_white`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(RED, Description, 1) AS BOOLEAN) AS `is_red`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(GREEN, Description, 1) AS BOOLEAN) AS `is_green`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(BLUE, Description, 1) AS BOOLEAN) AS `is_blue`&#39;&gt;]</div>

# %%
selected_cols.append(expr("*")) # column 타입이어야 함
selected_cols

display(df.select(*selected_cols).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>is_black</th><th>is_white</th><th>is_red</th><th>is_green</th><th>is_blue</th><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>false</td><td>true</td><td>false</td><td>false</td><td>false</td><td>536365</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>2.55</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>false</td><td>true</td><td>false</td><td>false</td><td>false</td><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>false</td><td>false</td><td>false</td><td>false</td><td>false</td><td>536365</td><td>84406B</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>2010-12-01T08:26:00.000+0000</td><td>2.75</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>false</td><td>false</td><td>false</td><td>false</td><td>false</td><td>536365</td><td>84029G</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>false</td><td>true</td><td>true</td><td>false</td><td>false</td><td>536365</td><td>84029E</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %%
display(df.select(*selected_cols).where(expr("is_white OR is_red")) \
  .select(col("Description")).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>WHITE METAL LANTERN</td></tr><tr><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr><tr><td>HAND WARMER RED POLKA DOT</td></tr><tr><td>RED COAT RACK PARIS FASHION</td></tr></tbody></table></div>

# %%
selected_cols
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: [Column&lt;b&#39;CAST(locate(BLACK, Description, 1) AS BOOLEAN) AS `is_black`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(WHITE, Description, 1) AS BOOLEAN) AS `is_white`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(RED, Description, 1) AS BOOLEAN) AS `is_red`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(GREEN, Description, 1) AS BOOLEAN) AS `is_green`&#39;&gt;,
#  Column&lt;b&#39;CAST(locate(BLUE, Description, 1) AS BOOLEAN) AS `is_blue`&#39;&gt;,
#  Column&lt;b&#39;unresolvedstar()&#39;&gt;]</div>

# %% [markdown]
# ## 6.6 날짜와 타임스탬프 데이터 타입 다루기
# - 스파크든 2가지 시간 정보만 다룸
#   - 날짜 정보만 가지는 date
#   - 날짜와 시간 정보를 모두 갖는 timestamp
# - 시간 설정이 필요하면 스파크 SQL설저의 spark.conf.sessionLocalTimeZone 속성으로 핸들링 가능
#   - 자바 TimeZone 포맷을 따라야 함
# - TimestampType 클래스는 초 단위 정밀도만 지원
#   - 초 단위 이상 정밀도 요구 시 long 데이터타입으로 데이터를 변환해 처리하는 우회 정책이 필요함

# %%
from pyspark.sql.functions import current_date, current_timestamp

dateDF = spark.range(10) \
      .withColumn("today", current_date()) \
      .withColumn("now", current_timestamp())
dateDF.createOrReplaceTempView("datatable")
dateDF.printSchema()

display(dateDF.limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>today</th><th>now</th></tr></thead><tbody><tr><td>0</td><td>2020-06-16</td><td>2020-06-16T12:57:58.263+0000</td></tr><tr><td>1</td><td>2020-06-16</td><td>2020-06-16T12:57:58.263+0000</td></tr><tr><td>2</td><td>2020-06-16</td><td>2020-06-16T12:57:58.263+0000</td></tr></tbody></table></div>

# %%
# 날짜를 더하거나 빽;
from pyspark.sql.functions import date_sub, date_add

display(dateDF.select(
  expr("today"),
  date_sub(col("today"), 5),
  date_add(expr("today"), 5)
))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>today</th><th>date_sub(today, 5)</th><th>date_add(today, 5)</th></tr></thead><tbody><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr><tr><td>2020-06-16</td><td>2020-06-11</td><td>2020-06-21</td></tr></tbody></table></div>

# %%
# 두 날짜 사이의 일/개월 수를 파악
from pyspark.sql.functions import datediff, months_between, to_date

# 현재 날짜에서 7일 제외 후 datediff결과 확인
display(dateDF.withColumn("week_ago", date_sub(col("today"), 7))\
  .select(datediff(col("week_ago"), col("today"))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datediff(week_ago, today)</th></tr></thead><tbody><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr><tr><td>-7</td></tr></tbody></table></div>

# %%
# 개월 수 차이 파악
display(dateDF.select(
  to_date(lit("2016-01-01")).alias("start"),
  to_date(lit("2017-05-22")).alias("end"))\
  .select(months_between(col("start"), col("end"))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>months_between(start, end, true)</th></tr></thead><tbody><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr><tr><td>-16.67741935</td></tr></tbody></table></div>

# %%
# 문자열을 날짜로 변환
# 자바의 simpleDateFormat 클래스가 지원하는 포맷 사용 필요
from pyspark.sql.functions import to_date, lit

display(spark.range(5).withColumn("date", lit("2017-01-01"))\
  .select(to_date(col("date"))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_date(`date`)</th></tr></thead><tbody><tr><td>2017-01-01</td></tr><tr><td>2017-01-01</td></tr><tr><td>2017-01-01</td></tr><tr><td>2017-01-01</td></tr><tr><td>2017-01-01</td></tr></tbody></table></div>

# %%
# 파싱오류로 날짜가 null로 반환되는 사례
display(dateDF.select(to_date(lit("2016-20-12")), to_date(lit("2017-12-11"))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_date('2016-20-12')</th><th>to_date('2017-12-11')</th></tr></thead><tbody><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr><tr><td>null</td><td>2017-12-11</td></tr></tbody></table></div>

# %%
# SimpleDateFormat 표준을 활용해 날짜 포맷을 지정
from pyspark.sql.functions import to_date

dateFormat = 'yyyy-dd-MM'

cleanDateDF = spark.range(1).select(
  to_date(lit("2017-12-11"), dateFormat).alias('date'),
  to_date(lit("2017-20-12"), dateFormat).alias("date2")
)

cleanDateDF.createOrReplaceTempView("dateTable2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.sql("""
SELECT * FROM dateTable2
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>date2</th></tr></thead><tbody><tr><td>2017-11-12</td><td>2017-12-20</td></tr></tbody></table></div>

# %%
# 항상 날짜 포맷을 지정해야 하는 to_timestamp 함수
from pyspark.sql.functions import to_timestamp

display(cleanDateDF.select(to_timestamp(col("date"), dateFormat)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_timestamp(`date`, 'yyyy-dd-MM')</th></tr></thead><tbody><tr><td>2017-11-12T00:00:00.000+0000</td></tr></tbody></table></div>

# %%
# 날짜 비교
display(cleanDateDF.filter(col("date2") > lit("2017-12-12")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>date2</th></tr></thead><tbody><tr><td>2017-11-12</td><td>2017-12-20</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.7 null값 다루기
# - null값을 사용하는 것보다 명시적으로 사용하는 것이 항상 좋음
# - null값을 허용하지 않는 컬럼을 선언해도 강제성은 없음
# - nullable 속성은 스파크 SQL 옵티마이저가 해당 컬럼을 제어하는 동작을 단순하게 돕는 역할
# - null값을 다루는 방법은 2가지
#   - 명시적으로 null을 제거
#   - 전역 또는 컬럼 단위로 null 값을 특정 값으로 채움

# %% [markdown]
# ### 6.7.1 coalesce

# %%
from pyspark.sql.functions import coalesce

display(df.select(coalesce(col("Description"), col("CustomerID"))).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>coalesce(Description, CustomerID)</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td></tr><tr><td>WHITE METAL LANTERN</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td></tr><tr><td>KNITTED UNION FLAG HOT WATER BOTTLE</td></tr><tr><td>RED WOOLLY HOTTIE WHITE HEART.</td></tr><tr><td>SET 7 BABUSHKA NESTING BOXES</td></tr><tr><td>GLASS STAR FROSTED T-LIGHT HOLDER</td></tr><tr><td>HAND WARMER UNION JACK</td></tr><tr><td>HAND WARMER RED POLKA DOT</td></tr><tr><td>ASSORTED COLOUR BIRD ORNAMENT</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.7.2 ifnull, nullif, nvl, nvl2
# - SQL 함수이며 DataFrame의 select 표혀식으로 사용 가능
#   - ifnull(null, 'return_value') : 두 번째 값을, 아니라면 첫번쨰 값을 반환
#   - nullif('value', 'value') : 두 값이 같으면 null
#   - nvl(null, 'return_value') : 두 번째 값을, 아니라면 첫 번째 값을 반환
#   - nvl2('not_null', 'return_value', 'else_value') : 두 번째 값을, 아니라면 세번째 값을 반환

# %%
display(spark.sql("""
SELECT
    ifnull(null, 'return_value'),
    nullif('value', 'value'),
    nvl(null, 'return_value'),
    nvl2('not null', 'return_value', 'else_value')
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ifnull(NULL, 'return_value')</th><th>nullif('value', 'value')</th><th>nvl(NULL, 'return_value')</th><th>nvl2('not null', 'return_value', 'else_value')</th></tr></thead><tbody><tr><td>return_value</td><td>null</td><td>return_value</td><td>return_value</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.7.3 drop
# - null 값을 가진 로우를 제거

# %%
df.na.drop()
df.na.drop('any').show(1) # 로우 컬럼 값 중에서 하나라도 null이면 제거
df.na.drop('all').show(1) # 로우 컬럼 값 중에서 모두 null이면 제거
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# InvoiceNo|StockCode|         Description|Quantity|        InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
#    536365|   85123A|WHITE HANGING HEA...|       6|2010-12-01 08:26:00|     2.55|   17850.0|United Kingdom|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# only showing top 1 row
#
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# InvoiceNo|StockCode|         Description|Quantity|        InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
#    536365|   85123A|WHITE HANGING HEA...|       6|2010-12-01 08:26:00|     2.55|   17850.0|United Kingdom|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# only showing top 1 row
#
# </div>

# %%
# 배열 형태의 컬럼을 인수로 전달 가능
display(df.na.drop("all", subset = ("StockCode", "InvoiceNo")).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536365</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>2.55</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84406B</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>2010-12-01T08:26:00.000+0000</td><td>2.75</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029G</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029E</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>22752</td><td>SET 7 BABUSHKA NESTING BOXES</td><td>2</td><td>2010-12-01T08:26:00.000+0000</td><td>7.65</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536365</td><td>21730</td><td>GLASS STAR FROSTED T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>4.25</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22633</td><td>HAND WARMER UNION JACK</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22632</td><td>HAND WARMER RED POLKA DOT</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84879</td><td>ASSORTED COLOUR BIRD ORNAMENT</td><td>32</td><td>2010-12-01T08:34:00.000+0000</td><td>1.69</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22745</td><td>POPPY'S PLAYHOUSE BEDROOM </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22748</td><td>POPPY'S PLAYHOUSE KITCHEN</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22749</td><td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td><td>8</td><td>2010-12-01T08:34:00.000+0000</td><td>3.75</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22310</td><td>IVORY KNITTED MUG COSY </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>1.65</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84969</td><td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>4.25</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22623</td><td>BOX OF VINTAGE JIGSAW BLOCKS </td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22622</td><td>BOX OF VINTAGE ALPHABET BLOCKS</td><td>2</td><td>2010-12-01T08:34:00.000+0000</td><td>9.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21754</td><td>HOME BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21755</td><td>LOVE BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047.0</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21777</td><td>RECIPE BOX WITH METAL HEART</td><td>4</td><td>2010-12-01T08:34:00.000+0000</td><td>7.95</td><td>13047.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.7.4 fill
# - fill : null을 특정한 값으로 채움

# %%
from pyspark.sql import Row
from pyspark.sql.types import StructField, StructType, StringType, DoubleType

myManualSchema = StructType([
  StructField("string_null", StringType(), True),
  StructField("string2_null", StringType(), True),
  StructField("number_null", DoubleType(), True)
])

myRows = []
myRows.append(Row("Hello", None, float(5))) # string 컬럼에 null 포함
myRows.append(Row(None, 'World', None))

myDF = spark.createDataFrame(myRows, myManualSchema)
display(myDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>null</td><td>5.0</td></tr><tr><td>null</td><td>World</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# - fill 함수는 DataType이 동일한 컬럼의 null만 치환
# - 숫자형 또한 치환할 값의 DataType이 동일해야 함

# %%
display(myDF.na.fill("All null values become this string")) # 동일한 string타입 컬럼의 null만 치환하는 것을 볼 수 있음
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>All null values become this string</td><td>5.0</td></tr><tr><td>All null values become this string</td><td>World</td><td>null</td></tr></tbody></table></div>

# %%
display(myDF.na.fill(5.0)) # 숫자형 또한 동일한 데이터타입만 치환하는 것을 볼 수 있음
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>null</td><td>5.0</td></tr><tr><td>null</td><td>World</td><td>5.0</td></tr></tbody></table></div>

# %%
# 딕셔너리 타입을 사용해서 다수의 컬럼에 fill메서드를 적용
fill_cols_vals = {'number_null' : 5.0, "string_null" : "no_value"}
display(myDF.na.fill(fill_cols_vals))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>null</td><td>5.0</td></tr><tr><td>no_value</td><td>World</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.7.5 replace

# %%
# 조건에 따라 다른 값으로 대체
display(myDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>null</td><td>5.0</td></tr><tr><td>null</td><td>World</td><td>null</td></tr></tbody></table></div>

# %%
display(myDF.na.replace([""], ["Hello"], "string_null"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>string_null</th><th>string2_null</th><th>number_null</th></tr></thead><tbody><tr><td>Hello</td><td>null</td><td>5.0</td></tr><tr><td>null</td><td>World</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.8 정렬하기
# - asc_nulls_first, desc_nulls_first, asc_nulls_last, desc_nulls_last

# %% [markdown]
# ## 6.9 복합 데이터 다루기
# - 구조체, 배열, 맵
#
# ### 6.9.1 구조체
# - DataFrame 내부의 DataFrame
# - 다수의 컬럼을 괄호로 묶어 생성 가능
# - 문법에 점(.)을 사용하거나 getField 메서드를 사용
# - (*\) 문자로 모든 값을 조회할 수 있음

# %%
from pyspark.sql.functions import struct

complexDF = df.select(struct("Description", "InvoiceNo").alias("complex"))
complexDF.createOrReplaceTempView("complexDF")
display(complexDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>complex</th></tr></thead><tbody><tr><td>List(WHITE HANGING HEART T-LIGHT HOLDER, 536365)</td></tr><tr><td>List(WHITE METAL LANTERN, 536365)</td></tr><tr><td>List(CREAM CUPID HEARTS COAT HANGER, 536365)</td></tr><tr><td>List(KNITTED UNION FLAG HOT WATER BOTTLE, 536365)</td></tr><tr><td>List(RED WOOLLY HOTTIE WHITE HEART., 536365)</td></tr></tbody></table></div>

# %%
# 아래의 연산은 모두 동일
complexDF.select("complex.Description", "complex.InvoiceNo")
complexDF.select(col("complex").getField("Description"), col("complex").getField("InvoiceNo"))
complexDF.select("complex.*")
complexDF.select(col("complex.*"))
display(complexDF.selectExpr("complex.*").limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th><th>InvoiceNo</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>536365</td></tr><tr><td>WHITE METAL LANTERN</td><td>536365</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td><td>536365</td></tr><tr><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>536365</td></tr><tr><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>536365</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.9.2 배열
# - 데이터에서 Description 컬럼의 모든 단어를 하나의 로우로 변환

# %% [markdown]
# ### Split

# %%
from pyspark.sql.functions import split

display(df.select(split(col("Description"), " ")).limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>split(Description,  )</th></tr></thead><tbody><tr><td>List(WHITE, HANGING, HEART, T-LIGHT, HOLDER)</td></tr><tr><td>List(WHITE, METAL, LANTERN)</td></tr></tbody></table></div>

# %%
""" 배열값의 조회 """
display(df.select(split(col("Description"), " ").alias("array_col"))\
    .selectExpr("array_col[0]", "array_col[1]", "array_col[2]").limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array_col[0]</th><th>array_col[1]</th><th>array_col[2]</th></tr></thead><tbody><tr><td>WHITE</td><td>HANGING</td><td>HEART</td></tr><tr><td>WHITE</td><td>METAL</td><td>LANTERN</td></tr></tbody></table></div>

# %% [markdown]
# ### 배열의 길이

# %%
# 배열의 길이 : size 함수
from pyspark.sql.functions import size

display(df.select(size(split(col("Description"), " "))).limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>size(split(Description,  ))</th></tr></thead><tbody><tr><td>5</td></tr><tr><td>3</td></tr></tbody></table></div>

# %% [markdown]
# ### array_contains
# - array_contains 함수를 사용해 배열에 특정 값이 존재하는지 확인

# %%
from pyspark.sql.functions import array_contains

display(df.select(array_contains(split(col("Description"), " "), "WHITE")).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array_contains(split(Description,  ), WHITE)</th></tr></thead><tbody><tr><td>true</td></tr><tr><td>true</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>true</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ### explode
# - 배열 타입의 컬럼을 입력받고 컬럼의 배열값에 포함된 모든 값을 로우로 변환

# %%
from pyspark.sql.functions import split, explode

explodedDF = df.withColumn("splitted", split(col("Description"), " "))\
  .withColumn("exploded", explode(col("splitted")))\
  .select("Description", "InvoiceNo", "exploded")

print(df.select("Description").count())
print(explodedDF.select("exploded").count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3108
# 14414
# </div>

# %%
explodedDF.select("Description", "exploded").count() # 큰 쪽으로 카운드
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: 14414</div>

# %%
display(explodedDF.select("Description", "exploded").limit(10)) # Description 컬럼이 Group이 되어 중복됨
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Description</th><th>exploded</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>WHITE</td></tr><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>HANGING</td></tr><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>HEART</td></tr><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>T-LIGHT</td></tr><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>HOLDER</td></tr><tr><td>WHITE METAL LANTERN</td><td>WHITE</td></tr><tr><td>WHITE METAL LANTERN</td><td>METAL</td></tr><tr><td>WHITE METAL LANTERN</td><td>LANTERN</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td><td>CREAM</td></tr><tr><td>CREAM CUPID HEARTS COAT HANGER</td><td>CUPID</td></tr></tbody></table></div>

# %% [markdown]
# ### 6.9.3 맵
# - map 함수와 컬럼의 키 값 쌍을 이용해 생성
# - 적합한 키를 사용해 데이터를 조회할 수 있으며 해당키가 없다면 null값을 반환함

# %%
from pyspark.sql.functions import create_map

display(df.select(create_map(col("Description"), col("InvoiceNo")).alias("complex_map")).limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>complex_map</th></tr></thead><tbody><tr><td>Map(WHITE HANGING HEART T-LIGHT HOLDER -> 536365)</td></tr><tr><td>Map(WHITE METAL LANTERN -> 536365)</td></tr></tbody></table></div>

# %%
# 맵의 데이터 조회
display(df.select(create_map(col("Description"), col("InvoiceNo")).alias("complex_map"))\
    .selectExpr("complex_map['WHITE METAL LANTERN']").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>complex_map[WHITE METAL LANTERN]</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>536365</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

# %%
# 맵 분해
display(df.select(create_map(col("Description"), col("InvoiceNo")).alias("complex_map")) \
  .selectExpr("explode(complex_map)").limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>536365</td></tr><tr><td>WHITE METAL LANTERN</td><td>536365</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.10 JSON 다루기

# %%
jsonDF = spark.range(1).selectExpr("""
  '{"myJSONKey" : {"myJSONValue" : [1, 2, 3]}}' as jsonString
""")

display(jsonDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>jsonString</th></tr></thead><tbody><tr><td>{"myJSONKey" : {"myJSONValue" : [1, 2, 3]}}</td></tr></tbody></table></div>

# %%
# 인라인 쿼리로 JSON 조회하기
from pyspark.sql.functions import get_json_object, json_tuple

display(jsonDF.select(
  col("jsonString"),
  get_json_object(col("jsonString"), "$.myJSONKey").alias("get_json_object1"),
  get_json_object(col("jsonString"), "$.myJSONKey.myJSONValue").alias("get_json_object2"),
  get_json_object(col("jsonString"), "$.myJSONKey.myJSONValue[0]").alias("get_json_object3"),
  json_tuple(col("jsonString"), "myJSONKey")
).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>jsonString</th><th>get_json_object1</th><th>get_json_object2</th><th>get_json_object3</th><th>c0</th></tr></thead><tbody><tr><td>{"myJSONKey" : {"myJSONValue" : [1, 2, 3]}}</td><td>{"myJSONValue":[1,2,3]}</td><td>[1,2,3]</td><td>1</td><td>{"myJSONValue":[1,2,3]}</td></tr></tbody></table></div>

# %%
# StructType을 Json 문자열로 변경
from pyspark.sql.functions import to_json

display(df.selectExpr("(InvoiceNo, Description) as myStruct") \
  .select(to_json(col("myStruct"))).limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>structstojson(myStruct)</th></tr></thead><tbody><tr><td>{"InvoiceNo":"536365","Description":"WHITE HANGING HEART T-LIGHT HOLDER"}</td></tr><tr><td>{"InvoiceNo":"536365","Description":"WHITE METAL LANTERN"}</td></tr><tr><td>{"InvoiceNo":"536365","Description":"CREAM CUPID HEARTS COAT HANGER"}</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import from_json
from pyspark.sql.types import *

parseSchema = StructType([
  StructField("InvoiceNo", StringType(), True),
  StructField("Description", StringType(), True),
])

display(df.selectExpr("(InvoiceNo, Description) as myStruct") \
  .select(to_json(col("myStruct")).alias("newJSON")) \
  .select(from_json(col("newJSON"), parseSchema), col("newJSON")).limit(2)) # 키를 컬럼명으로 값을 로우로 변경
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>jsontostructs(newJSON)</th><th>newJSON</th></tr></thead><tbody><tr><td>List(536365, WHITE HANGING HEART T-LIGHT HOLDER)</td><td>{"InvoiceNo":"536365","Description":"WHITE HANGING HEART T-LIGHT HOLDER"}</td></tr><tr><td>List(536365, WHITE METAL LANTERN)</td><td>{"InvoiceNo":"536365","Description":"WHITE METAL LANTERN"}</td></tr></tbody></table></div>

# %% [markdown]
# ## 6.11 사용자 정의 함수
# - User defined function(UDF)는 레포트별로 데이터를 처리하는 함수이며, SparkSession이나 Context에서 사용할 수 있도록 임시 함수 형태로 등록됨
# - 내장 함수가 제공하는 코드 생성 기능의 장점을 활용할 수 없어 약간의 성능 저하 발생
# - 언어별로 성능차이가 존재, 파이썬에서도 사용할 수 있으므로 자바나 스칼라도 함수 작성을 추천함

# %%
udfExDF = spark.range(5).toDF("num")

def power3(double_value):
  return double_value ** 3

power3(2.0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[69]: 8.0</div>

# %%
from pyspark.sql.functions import udf

power3udf = udf(power3)

display(udfExDF.select(power3udf(col("num"))).limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>power3(num)</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>8</td></tr></tbody></table></div>
